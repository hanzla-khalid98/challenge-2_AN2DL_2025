# %% [markdown]
# <a href="https://colab.research.google.com/github/hanzla-khalid98/challenge-2_AN2DL_2025/blob/main/notebooks/CNNInception_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Inception block CNN model

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Set seed for reproducibility
SEED = 42

# Import necessary libraries
import os
from pathlib import Path


# Set environment variables before importing modules
os.environ['PYTHONHASHSEED'] = str(SEED)
os.environ['MPLCONFIGDIR'] = os.getcwd() + '/configs/'

# Suppress warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

# Import necessary modules
import logging
import random
import numpy as np

# Set seeds for random number generators in NumPy and Python
np.random.seed(SEED)
random.seed(SEED)

# Import PyTorch
import torch
torch.manual_seed(SEED)
from torch import nn
from torchsummary import summary
from torch.utils.tensorboard import SummaryWriter
import torchvision
from torchvision import datasets
import torchvision.transforms.v2 as transforms
from torch.utils.data import TensorDataset, DataLoader

# Configurazione di TensorBoard e directory
logs_dir = "tensorboard"
# !pkill -f tensorboard
# %load_ext tensorboard
# !mkdir -p models

if torch.cuda.is_available():
    device = torch.device("cuda")
    torch.cuda.manual_seed_all(SEED)
    torch.backends.cudnn.benchmark = True
else:
    device = torch.device("cpu")

print(f"PyTorch version: {torch.__version__}")
print(f"Device: {device}")

# Import other libraries
import copy
import shutil
from itertools import product
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.model_selection import train_test_split
from PIL import Image
import matplotlib.gridspec as gridspec

# Configure plot display settings
sns.set(font_scale=1.4)
sns.set_style('white')
plt.rc('font', size=14)
# %matplotlib inline
# Out:
# PyTorch version: 2.9.0+cu126
# Device: cuda

# %% [markdown]
# ## Load the dataset

# %%
# Load the preprocessed tensors so we can skip the heavy CSV wrangling

dataset_path = Path("/content/drive/MyDrive/data/dataset_tiling_challenge_2.pt")

if not dataset_path.exists():
    raise FileNotFoundError(
        f"dataset.pt not found"
    )

try:
    bundle = torch.load(dataset_path, map_location="cpu", weights_only=False)
except RuntimeError as err:
        raise


X_train = torch.from_numpy(bundle["X_train"]).permute(0, 3, 1, 2).float()
y_train = torch.from_numpy(bundle["y_train"]).view(-1).long()
X_val = torch.from_numpy(bundle["X_val"]).permute(0, 3, 1, 2).float()
y_val = torch.from_numpy(bundle["y_val"]).view(-1).long()
X_test = torch.from_numpy(bundle["X_test"]).permute(0, 3, 1, 2).float()

if "images_test_name" in bundle:
    images_test_name = bundle["images_test_name"]
else:
    images_test_name = None


print(f"Train tensor shape: {tuple(X_train.shape)}")
print(f"Validation tensor shape: {tuple(X_val.shape)}")
print(f"Test tensor shape: {tuple(X_test.shape)}")
# Out:
# Train tensor shape: (5562, 3, 128, 128)
# Validation tensor shape: (619, 3, 128, 128)
# Test tensor shape: (4414, 3, 128, 128)

# %%
class AugmentedDataset(torch.utils.data.Dataset):
    """
    Custom PyTorch Dataset that applies data augmentation transforms using transforms v2.

    Following the recommended approach from torchvision documentation:
    - Use ToImage() to convert PIL to tensor
    - Use ToDtype(torch.float32, scale=True) to convert to float and scale to [0, 1]

    Args:
        data (np.ndarray): Input images with shape (N, H, W, C)
        labels (np.ndarray): Labels with shape (N,)
        transform (callable, optional): Transform to apply to images
    """
    def __init__(self, data, labels, images_id=None, transform=None):
        self.data = data
        self.labels = labels
        self.images_id = images_id
        self.transform = transform

        # Base transform: convert to tensor (following v2 guidelines)
        self.to_tensor = transforms.Compose([
            transforms.ToImage(), # This will handle (H,W,C) to (C,H,W) if needed, but data is already (C,H,W)
            transforms.ToDtype(torch.float32, scale=True)
        ])

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        # Get image and label
        image = self.data[idx] # This is already a torch.Tensor (float32, 0-1, CHW) due to previous data loading fix

        # Apply base transform: already (CHW), ToImage will pass through, ToDtype ensures float32
        image_tensor = self.to_tensor(image)

        # Apply additional transforms if provided
        if self.transform:
            image_tensor = self.transform(image_tensor)

        if self.images_id is not None:
            return image_tensor , self.images_id[idx]
        if self.labels is None:
            return image_tensor
        label = self.labels[idx]

        return image_tensor, torch.tensor(label, dtype=torch.long)


train_augmentation = transforms.Compose([
    transforms.RandomHorizontalFlip(p=0.5),
    #transforms.RandomVerticalFlip(p=0.2),
    # transforms.RandomRotation(15),
    # transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
    transforms.RandomErasing(p=1.0, scale=(0.02, 0.33), ratio=(0.3, 3.3), value=0),
])

train_ds = AugmentedDataset(X_train, y_train, transform=train_augmentation)
val_ds   = AugmentedDataset(X_val, y_val, transform=None)
test_ds  = AugmentedDataset(X_test, labels=None, images_id=images_test_name, transform=None)

# %%
BATCH_SIZE = 64
EVAL_BATCH_SIZE = 128


def make_loader(dataset, batch_size, shuffle, drop_last):
    """Wrap tensors in a DataLoader."""
    # Setting num_workers to 0 disables multiprocessing for data loading
    # and often resolves issues with FileNotFoundError in _pin_memory_loop
    # Set pin_memory to False as it's often problematic with num_workers > 0 in Colab
    # If performance is an issue, consider experimenting with num_workers = 1 and pin_memory=True
    num_workers = 0 # os.cpu_count() or 2
    return DataLoader(
        dataset,
        batch_size=batch_size,
        shuffle=shuffle,
        drop_last=drop_last,
        num_workers=num_workers,
        pin_memory=False, # Changed to False
        pin_memory_device="cuda" if torch.cuda.is_available() else "",
        prefetch_factor=None, # Changed to None as num_workers is 0
    )

train_loader = make_loader(train_ds, BATCH_SIZE, shuffle=True, drop_last=False)
val_loader = make_loader(val_ds, EVAL_BATCH_SIZE, shuffle=False, drop_last=False)
test_loader = make_loader(test_ds, EVAL_BATCH_SIZE, shuffle=False, drop_last=False)


# Handy metadata for configuring the model
input_size = X_train.shape[1:]
num_classes = len(torch.unique(y_train))
print(f"Input size: {input_size}, classes: {num_classes}")
# Out:
# Input size: torch.Size([3, 128, 128]), classes: 4

# %%
# Fetch a batch to capture the per-sample input shape for summaries
for xb, yb in train_loader:
    input_shape = xb.shape[1:]
    num_classes = len(np.unique(yb.cpu().numpy()))
    break

print(f"Input shape per sample: {input_shape}")
# Out:
# Input shape per sample: torch.Size([3, 128, 128])

# %% [markdown]
# 🛠️ Inception Block (GoogLeNet, 2014)

# %% [markdown]
# Key Features and Achievements
#
# Multi-scale feature processing
# Winner of ILSVRC 2014
# Key building block:
#
# Parallel paths with different kernels
# 1x1 bottleneck for efficiency
# Feature concatenation
# Impact:
#
# Established multi-path processing
# Introduced 1x1 bottleneck concept

# %%
import torch.nn.functional as F

class InceptionBlock(nn.Module):
    def __init__(self, in_channels, out_channels, use_stride=False, stride_value=2,
                 padding_size=1, pool_size=2, stack=2):
        super().__init__()
        self.stack = stack
        self.use_stride = use_stride
        self.stride_value = stride_value
        self.padding_size = padding_size
        self.pool_size = pool_size

        self.inception_modules = nn.ModuleList()
        current_channels = in_channels

        for _ in range(stack):
            module = nn.ModuleDict({
                'conv1': nn.Sequential(
                    nn.Conv2d(current_channels, out_channels // 4, kernel_size=1, stride=1, padding=0),
                    nn.BatchNorm2d(out_channels // 4),
                    nn.ReLU()
                ),
                'conv3_reduce': nn.Sequential(
                    nn.Conv2d(current_channels, out_channels // 8, kernel_size=1, stride=1, padding=0),
                    nn.BatchNorm2d(out_channels // 8),
                    nn.ReLU()
                ),
                'conv3': nn.Sequential(
                    nn.Conv2d(out_channels // 8, out_channels // 4, kernel_size=3,
                              stride=stride_value if use_stride else 1, padding=padding_size),
                    nn.BatchNorm2d(out_channels // 4),
                    nn.ReLU()
                ),
                'conv5_reduce': nn.Sequential(
                    nn.Conv2d(current_channels, out_channels // 12, kernel_size=1, stride=1, padding=0),
                    nn.BatchNorm2d(out_channels // 12),
                    nn.ReLU()
                ),
                'conv5': nn.Sequential(
                    nn.Conv2d(out_channels // 12, out_channels // 4, kernel_size=5,
                              stride=stride_value if use_stride else 1, padding=2*padding_size),
                    nn.BatchNorm2d(out_channels // 4),
                    nn.ReLU()
                ),
                'pool': nn.MaxPool2d(kernel_size=pool_size, stride=1, padding=pool_size//2),
                'pool_proj': nn.Sequential(
                    nn.Conv2d(current_channels, out_channels // 4, kernel_size=1, stride=1, padding=0),
                    nn.BatchNorm2d(out_channels // 4),
                    nn.ReLU()
                )
            })
            self.inception_modules.append(module)
            current_channels = out_channels

        self.downsample = nn.MaxPool2d(pool_size) if use_stride else nn.Identity()

    def forward(self, x):
        for module in self.inception_modules:
            conv1 = module['conv1'](x)
            conv3 = module['conv3'](module['conv3_reduce'](x))
            conv5 = module['conv5'](module['conv5_reduce'](x))
            pool_proj = module['pool_proj'](module['pool'](x))

            # Fix: match smallest H/W
            min_h = min(conv1.shape[2], conv3.shape[2], conv5.shape[2], pool_proj.shape[2])
            min_w = min(conv1.shape[3], conv3.shape[3], conv5.shape[3], pool_proj.shape[3])

            conv1 = conv1[:, :, :min_h, :min_w]
            conv3 = conv3[:, :, :min_h, :min_w]
            conv5 = conv5[:, :, :min_h, :min_w]
            pool_proj = pool_proj[:, :, :min_h, :min_w]

            x = torch.cat([conv1, conv3, conv5, pool_proj], dim=1)
        x = self.downsample(x)
        return x


class InceptionModel(nn.Module):
    def __init__(self, input_shape, output_shape,
                 dropout_rate=0.0, num_blocks=2,
                 use_stride=False, stride_value=2, padding_size=1, pool_size=2,
                 initial_channels=32, channel_multiplier=2,
                 stack=2):
        super().__init__()

        blocks = []
        in_channels = input_shape[0]
        filters = initial_channels

        for _ in range(num_blocks):
            blocks.append(InceptionBlock(
                in_channels=in_channels,
                out_channels=filters,
                use_stride=use_stride,
                stride_value=stride_value,
                padding_size=padding_size,
                pool_size=pool_size,
                stack=stack
            ))
            in_channels = filters
            filters *= channel_multiplier

        self.features = nn.Sequential(*blocks)
        self.gap = nn.AdaptiveAvgPool2d(1)
        self.flatten = nn.Flatten()
        self.dropout = nn.Dropout(dropout_rate)
        self.fc = nn.Linear(in_channels, output_shape)

    def forward(self, x):
        x = self.features(x)
        x = self.gap(x)
        x = self.flatten(x)
        x = self.dropout(x)
        x = self.fc(x)
        return F.softmax(x, dim=1)

# %% [markdown]
# ## training and evaluating functions

# %%
def train_one_epoch(model, train_loader, criterion, optimizer, scaler, device, l1_lambda=0, l2_lambda=0):
    """
    Perform one complete training epoch through the entire training dataset.

    Args:
        model (nn.Module): The neural network model to train
        train_loader (DataLoader): PyTorch DataLoader containing training data batches
        criterion (nn.Module): Loss function (e.g., CrossEntropyLoss, MSELoss)
        optimizer (torch.optim): Optimization algorithm (e.g., Adam, SGD)
        scaler (GradScaler): PyTorch's gradient scaler for mixed precision training
        device (torch.device): Computing device ('cuda' for GPU, 'cpu' for CPU)
        l1_lambda (float): Lambda for L1 regularization
        l2_lambda (float): Lambda for L2 regularization

    Returns:
        tuple: (average_loss, f1 score) - Training loss and f1 score for this epoch
    """
    model.train()  # Set model to training mode

    running_loss = 0.0
    all_predictions = []
    all_targets = []

    # Iterate through training batches
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        # Move data to device (GPU/CPU)
        inputs, targets = inputs.to(device), targets.to(device)

        # permute inputs (batch, channel, height, width)
        # inputs = inputs.permute(0, 3, 1, 2) # This line is now redundant after AugmentedDataset fix

        # Clear gradients from previous step
        optimizer.zero_grad(set_to_none=True)

        # Forward pass with mixed precision (if CUDA available)
        with torch.amp.autocast(device_type=device.type, enabled=(device.type == 'cuda')):
            logits = model(inputs)
            loss = criterion(logits, targets)

            # Add L1 and L2 regularization
            l1_norm = sum(p.abs().sum() for p in model.parameters())
            l2_norm = sum(p.pow(2).sum() for p in model.parameters())
            loss = loss + l1_lambda * l1_norm + l2_lambda * l2_norm


        # Backward pass with gradient scaling
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        # Accumulate metrics
        running_loss += loss.item() * inputs.size(0)
        predictions = logits.argmax(dim=1)
        all_predictions.append(predictions.cpu().numpy())
        all_targets.append(targets.cpu().numpy())

    # Calculate epoch metrics
    epoch_loss = running_loss / len(train_loader.dataset)
    epoch_f1 = f1_score(
        np.concatenate(all_targets),
        np.concatenate(all_predictions),
        average='weighted'
    )

    return epoch_loss, epoch_f1

# %%
def validate_one_epoch(model, val_loader, criterion, device):
    """
    Perform one complete validation epoch through the entire validation dataset.

    Args:
        model (nn.Module): The neural network model to evaluate (must be in eval mode)
        val_loader (DataLoader): PyTorch DataLoader containing validation data batches
        criterion (nn.Module): Loss function used to calculate validation loss
        device (torch.device): Computing device ('cuda' for GPU, 'cpu' for CPU)

    Returns:
        tuple: (average_loss, accuracy) - Validation loss and accuracy for this epoch

    Note:
        This function automatically sets the model to evaluation mode and disables
        gradient computation for efficiency during validation.
    """
    model.eval()  # Set model to evaluation mode

    running_loss = 0.0
    all_predictions = []
    all_targets = []

    # Disable gradient computation for validation
    with torch.no_grad():
        for inputs, targets in val_loader:
            # Move data to device
            inputs, targets = inputs.to(device), targets.to(device)

            # permute inputs (batch, channel, height, width)
            # inputs = inputs.permute(0, 3, 1, 2) # This line is now redundant after AugmentedDataset fix

            # Forward pass with mixed precision (if CUDA available)
            with torch.amp.autocast(device_type=device.type, enabled=(device.type == 'cuda')):
                logits = model(inputs)
                loss = criterion(logits, targets)

            # Accumulate metrics
            running_loss += loss.item() * inputs.size(0)
            predictions = logits.argmax(dim=1)
            all_predictions.append(predictions.cpu().numpy())
            all_targets.append(targets.cpu().numpy())

    # Calculate epoch metrics
    epoch_loss = running_loss / len(val_loader.dataset)
    epoch_accuracy = f1_score(
        np.concatenate(all_targets),
        np.concatenate(all_predictions),
        average='weighted'
    )

    return epoch_loss, epoch_accuracy

# %%
def fit(model, train_loader, val_loader, epochs, criterion, optimizer, scaler, scheduler, device,
        l1_lambda=0, l2_lambda=0, patience=0, evaluation_metric="val_f1", mode='max',
        restore_best_weights=True, writer=None, verbose=10, experiment_name=""):
    """
    Train the neural network model on the training data and validate on the validation data.

    Args:
        model (nn.Module): The neural network model to train
        train_loader (DataLoader): PyTorch DataLoader containing training data batches
        val_loader (DataLoader): PyTorch DataLoader containing validation data batches
        epochs (int): Number of training epochs
        criterion (nn.Module): Loss function (e.g., CrossEntropyLoss, MSELoss)
        optimizer (torch.optim): Optimization algorithm (e.g., Adam, SGD)
        scaler (GradScaler): PyTorch's gradient scaler for mixed precision training
        device (torch.device): Computing device ('cuda' for GPU, 'cpu' for CPU)
        l1_lambda (float): L1 regularization coefficient (default: 0)
        l2_lambda (float): L2 regularization coefficient (default: 0)
        patience (int): Number of epochs to wait for improvement before early stopping (default: 0)
        evaluation_metric (str): Metric to monitor for early stopping (default: "val_f1")
        mode (str): 'max' for maximizing the metric, 'min' for minimizing (default: 'max')
        restore_best_weights (bool): Whether to restore model weights from best epoch (default: True)
        writer (SummaryWriter, optional): TensorBoard SummaryWriter object for logging (default: None)
        verbose (int, optional): Frequency of printing training progress (default: 10)
        experiment_name (str, optional): Experiment name for saving models (default: "")

    Returns:
        tuple: (model, training_history) - Trained model and metrics history
    """

    # Initialize metrics tracking
    training_history = {
        'train_loss': [], 'val_loss': [],
        'train_f1': [], 'val_f1': []
    }

    # Configure early stopping if patience is set
    if patience > 0:
        patience_counter = 0
        best_metric = float('-inf') if mode == 'max' else float('inf')
        best_epoch = 0

    print(f"Training {epochs} epochs...")

    # Main training loop: iterate through epochs
    for epoch in range(1, epochs + 1):

        # Forward pass through training data, compute gradients, update weights
        train_loss, train_f1 = train_one_epoch(
            model, train_loader, criterion, optimizer, scaler, device, l1_lambda, l2_lambda
        )

        # Evaluate model on validation data without updating weights
        val_loss, val_f1 = validate_one_epoch(
            model, val_loader, criterion, device
        )

        scheduler.step()

        # Store metrics for plotting and analysis
        training_history['train_loss'].append(train_loss)
        training_history['val_loss'].append(val_loss)
        training_history['train_f1'].append(train_f1)
        training_history['val_f1'].append(val_f1)


        # Print progress every N epochs or on first epoch
        if verbose > 0:
            if epoch % verbose == 0 or epoch == 1:
                print(f"Epoch {epoch:3d}/{epochs} | "
                    f"Train: Loss={train_loss:.4f}, F1 Score={train_f1:.4f} | "
                    f"Val: Loss={val_loss:.4f}, F1 Score={val_f1:.4f}")

        # Early stopping logic: monitor metric and save best model
        if patience > 0:
            current_metric = training_history[evaluation_metric][-1]
            is_improvement = (current_metric > best_metric) if mode == 'max' else (current_metric < best_metric)

            if is_improvement:
                best_metric = current_metric
                best_epoch = epoch
                torch.save(model.state_dict(), "models/"+experiment_name+'_model.pt')
                patience_counter = 0
            else:
                patience_counter += 1
                if patience_counter >= patience:
                    print(f"Early stopping triggered after {epoch} epochs.")
                    break

    # Restore best model weights if early stopping was used
    if restore_best_weights and patience > 0:
        model.load_state_dict(torch.load("models/"+experiment_name+'_model.pt'))
        print(f"Best model restored from epoch {best_epoch} with {evaluation_metric} {best_metric:.4f}")

    # Save final model if no early stopping
    if patience == 0:
        torch.save(model.state_dict(), "models/"+experiment_name+'_model.pt')

    # Close TensorBoard writer
    if writer is not None:
        writer.close()

    return model, training_history

# %% [markdown]
# ## Hyperparameters

# %%
# Number of training epochs
LEARNING_RATE = 5e-4
EPOCHS = 200
PATIENCE = 100

# Regularisation
DROPOUT_RATE = 0.4        # Dropout probability
L1_LAMBDA = 0            # L1 penalty
L2_LAMBDA = 0            # L2 penalty

# Set up loss function and optimizer
criterion = nn.CrossEntropyLoss(label_smoothing=0.1)

# Print the defined parameters
print("Epochs:", EPOCHS)
print("Batch Size:", BATCH_SIZE)
print("Learning Rare:", LEARNING_RATE)
print("Dropout Rate:", DROPOUT_RATE)
print("L1 Penalty:", L1_LAMBDA)
print("L2 Penalty:", L2_LAMBDA)
# Out:
# Epochs: 200
# Batch Size: 64
# Learning Rare: 0.0005
# Dropout Rate: 0.4
# L1 Penalty: 0
# L2 Penalty: 0

# %%
# CNN Architecture parameters
# Number of convolutional blocks
NUM_BLOCKS = 3

# Number of conv layers per block
CONVS_PER_BLOCK = 2

# Use strided convolutions instead of pooling
USE_STRIDE = False

# Stride value when USE_STRIDE is True
STRIDE_VALUE = 2

# Padding size
PADDING_SIZE = 1

# Pooling size when USE_STRIDE is False
POOL_SIZE = 2

# Number of channels in first block
INITIAL_CHANNELS = 32

# Channel multiplication factor between blocks
CHANNEL_MULTIPLIER = 2

print("Num Blocks:", NUM_BLOCKS)
print("Convs per Block:", CONVS_PER_BLOCK)
print("Use Stride:", USE_STRIDE)
print("Stride Value:", STRIDE_VALUE)
print("Padding Size:", PADDING_SIZE)
print("Pool Size:", POOL_SIZE)
print("Initial Channels:", INITIAL_CHANNELS)
print("Channel Multiplier:", CHANNEL_MULTIPLIER)
# Out:
# Num Blocks: 3
# Convs per Block: 2
# Use Stride: False
# Stride Value: 2
# Padding Size: 1
# Pool Size: 2
# Initial Channels: 32
# Channel Multiplier: 2

# %% [markdown]
# ## Training

# %%
# Initialize best model tracking variables
best_model = None
best_performance = float('-inf')

# %%
inception_model = InceptionModel(
    input_shape=input_shape,
    output_shape=num_classes,
    dropout_rate=DROPOUT_RATE,
    num_blocks=NUM_BLOCKS,
    use_stride=USE_STRIDE,
    stride_value=STRIDE_VALUE,
    padding_size=PADDING_SIZE,
    pool_size=POOL_SIZE,
    initial_channels=INITIAL_CHANNELS,
    channel_multiplier=CHANNEL_MULTIPLIER
).to(device)

# Affichage du résumé
summary(inception_model, input_size=input_shape)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 8, 128, 128]              32
#        BatchNorm2d-2          [-1, 8, 128, 128]              16
#               ReLU-3          [-1, 8, 128, 128]               0
#             Conv2d-4          [-1, 4, 128, 128]              16
#        BatchNorm2d-5          [-1, 4, 128, 128]               8
#               ReLU-6          [-1, 4, 128, 128]               0
#             Conv2d-7          [-1, 8, 128, 128]             296
#        BatchNorm2d-8          [-1, 8, 128, 128]              16
#               ReLU-9          [-1, 8, 128, 128]               0
#            Conv2d-10          [-1, 2, 128, 128]               8
#       BatchNorm2d-11          [-1, 2, 128, 128]               4
#              ReLU-12          [-1, 2, 128, 128]               0
#            Conv2d-13          [-1, 8, 128, 128]             408
#       BatchNorm2d-14          [-1, 8, 128, 128]              16
#              ReLU-15          [-1, 8, 128, 128]               0
#         MaxPool2d-16          [-1, 3, 129, 129]               0
#            Conv2d-17          [-1, 8, 129, 129]              32
#       BatchNorm2d-18          [-1, 8, 129, 129]              16
#              ReLU-19          [-1, 8, 129, 129]               0
#            Conv2d-20          [-1, 8, 128, 128]             264
#       BatchNorm2d-21          [-1, 8, 128, 128]              16
#              ReLU-22          [-1, 8, 128, 128]               0
#            Conv2d-23          [-1, 4, 128, 128]             132
#       BatchNorm2d-24          [-1, 4, 128, 128]               8
#              ReLU-25          [-1, 4, 128, 128]               0
#            Conv2d-26          [-1, 8, 128, 128]             296
#       BatchNorm2d-27          [-1, 8, 128, 128]              16
#              ReLU-28          [-1, 8, 128, 128]               0
#            Conv2d-29          [-1, 2, 128, 128]              66
#       BatchNorm2d-30          [-1, 2, 128, 128]               4
#              ReLU-31          [-1, 2, 128, 128]               0
#            Conv2d-32          [-1, 8, 128, 128]             408
#       BatchNorm2d-33          [-1, 8, 128, 128]              16
#              ReLU-34          [-1, 8, 128, 128]               0
#         MaxPool2d-35         [-1, 32, 129, 129]               0
#            Conv2d-36          [-1, 8, 129, 129]             264
#       BatchNorm2d-37          [-1, 8, 129, 129]              16
#              ReLU-38          [-1, 8, 129, 129]               0
#          Identity-39         [-1, 32, 128, 128]               0
#    InceptionBlock-40         [-1, 32, 128, 128]               0
#            Conv2d-41         [-1, 16, 128, 128]             528
#       BatchNorm2d-42         [-1, 16, 128, 128]              32
#              ReLU-43         [-1, 16, 128, 128]               0
#            Conv2d-44          [-1, 8, 128, 128]             264
#       BatchNorm2d-45          [-1, 8, 128, 128]              16
#              ReLU-46          [-1, 8, 128, 128]               0
#            Conv2d-47         [-1, 16, 128, 128]           1,168
#       BatchNorm2d-48         [-1, 16, 128, 128]              32
#              ReLU-49         [-1, 16, 128, 128]               0
#            Conv2d-50          [-1, 5, 128, 128]             165
#       BatchNorm2d-51          [-1, 5, 128, 128]              10
#              ReLU-52          [-1, 5, 128, 128]               0
#            Conv2d-53         [-1, 16, 128, 128]           2,016
#       BatchNorm2d-54         [-1, 16, 128, 128]              32
#              ReLU-55         [-1, 16, 128, 128]               0
#         MaxPool2d-56         [-1, 32, 129, 129]               0
#            Conv2d-57         [-1, 16, 129, 129]             528
#       BatchNorm2d-58         [-1, 16, 129, 129]              32
#              ReLU-59         [-1, 16, 129, 129]               0
#            Conv2d-60         [-1, 16, 128, 128]           1,040
#       BatchNorm2d-61         [-1, 16, 128, 128]              32
#              ReLU-62         [-1, 16, 128, 128]               0
#            Conv2d-63          [-1, 8, 128, 128]             520
#       BatchNorm2d-64          [-1, 8, 128, 128]              16
#              ReLU-65          [-1, 8, 128, 128]               0
#            Conv2d-66         [-1, 16, 128, 128]           1,168
#       BatchNorm2d-67         [-1, 16, 128, 128]              32
#              ReLU-68         [-1, 16, 128, 128]               0
#            Conv2d-69          [-1, 5, 128, 128]             325
#       BatchNorm2d-70          [-1, 5, 128, 128]              10
#              ReLU-71          [-1, 5, 128, 128]               0
#            Conv2d-72         [-1, 16, 128, 128]           2,016
#       BatchNorm2d-73         [-1, 16, 128, 128]              32
#              ReLU-74         [-1, 16, 128, 128]               0
#         MaxPool2d-75         [-1, 64, 129, 129]               0
#            Conv2d-76         [-1, 16, 129, 129]           1,040
#       BatchNorm2d-77         [-1, 16, 129, 129]              32
#              ReLU-78         [-1, 16, 129, 129]               0
#          Identity-79         [-1, 64, 128, 128]               0
#    InceptionBlock-80         [-1, 64, 128, 128]               0
#            Conv2d-81         [-1, 32, 128, 128]           2,080
#       BatchNorm2d-82         [-1, 32, 128, 128]              64
#              ReLU-83         [-1, 32, 128, 128]               0
#            Conv2d-84         [-1, 16, 128, 128]           1,040
#       BatchNorm2d-85         [-1, 16, 128, 128]              32
#              ReLU-86         [-1, 16, 128, 128]               0
#            Conv2d-87         [-1, 32, 128, 128]           4,640
#       BatchNorm2d-88         [-1, 32, 128, 128]              64
#              ReLU-89         [-1, 32, 128, 128]               0
#            Conv2d-90         [-1, 10, 128, 128]             650
#       BatchNorm2d-91         [-1, 10, 128, 128]              20
#              ReLU-92         [-1, 10, 128, 128]               0
#            Conv2d-93         [-1, 32, 128, 128]           8,032
#       BatchNorm2d-94         [-1, 32, 128, 128]              64
#              ReLU-95         [-1, 32, 128, 128]               0
#         MaxPool2d-96         [-1, 64, 129, 129]               0
#            Conv2d-97         [-1, 32, 129, 129]           2,080
#       BatchNorm2d-98         [-1, 32, 129, 129]              64
#              ReLU-99         [-1, 32, 129, 129]               0
#           Conv2d-100         [-1, 32, 128, 128]           4,128
#      BatchNorm2d-101         [-1, 32, 128, 128]              64
#             ReLU-102         [-1, 32, 128, 128]               0
#           Conv2d-103         [-1, 16, 128, 128]           2,064
#      BatchNorm2d-104         [-1, 16, 128, 128]              32
#             ReLU-105         [-1, 16, 128, 128]               0
#           Conv2d-106         [-1, 32, 128, 128]           4,640
#      BatchNorm2d-107         [-1, 32, 128, 128]              64
#             ReLU-108         [-1, 32, 128, 128]               0
#           Conv2d-109         [-1, 10, 128, 128]           1,290
#      BatchNorm2d-110         [-1, 10, 128, 128]              20
#             ReLU-111         [-1, 10, 128, 128]               0
#           Conv2d-112         [-1, 32, 128, 128]           8,032
#      BatchNorm2d-113         [-1, 32, 128, 128]              64
#             ReLU-114         [-1, 32, 128, 128]               0
#        MaxPool2d-115        [-1, 128, 129, 129]               0
#           Conv2d-116         [-1, 32, 129, 129]           4,128
#      BatchNorm2d-117         [-1, 32, 129, 129]              64
#             ReLU-118         [-1, 32, 129, 129]               0
#         Identity-119        [-1, 128, 128, 128]               0
#   InceptionBlock-120        [-1, 128, 128, 128]               0
# AdaptiveAvgPool2d-121            [-1, 128, 1, 1]               0
#          Flatten-122                  [-1, 128]               0
#          Dropout-123                  [-1, 128]               0
#           Linear-124                    [-1, 4]             516
# ================================================================
# Total params: 57,396
# Trainable params: 57,396
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.19
# Forward/backward pass size (MB): 299.42
# Params size (MB): 0.22
# Estimated Total Size (MB): 299.83
# ----------------------------------------------------------------

# %%
# Define optimizer with L2 regularization
optimizer = torch.optim.AdamW(inception_model.parameters(), lr=LEARNING_RATE, weight_decay=L2_LAMBDA)

# Enable mixed precision training for GPU acceleration
scaler = torch.amp.GradScaler(enabled=(device.type == 'cuda'))

scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
    optimizer,
    T_max=EPOCHS,       # your total epochs
    eta_min=1e-6
)

# %%
experiment_name = "cnn_baselinev2_3"

writer = SummaryWriter(f"./{logs_dir}/cnn")


# %%time
# Train model and track training history
inception_model, training_history = fit(
    model=inception_model,
    train_loader=train_loader,
    val_loader=val_loader,
    epochs=EPOCHS,
    criterion=criterion,
    optimizer=optimizer,
    scaler=scaler,
    scheduler=scheduler,
    device=device,
    l1_lambda=L1_LAMBDA,
    l2_lambda=L2_LAMBDA,
    patience=PATIENCE,
    evaluation_metric="val_f1",
    mode='max',
    restore_best_weights=True,
    writer=writer,
    verbose=1,
    experiment_name=experiment_name,
    )

# Update best model if current performance is superior
if training_history['val_f1'][-1] > best_performance:
    best_model = inception_model
    best_performance = training_history['val_f1'][-1]
# Out:
# Training 200 epochs...
# Epoch   1/200 | Train: Loss=1.3294, F1 Score=0.3516 | Val: Loss=1.3085, F1 Score=0.3643
# Epoch   2/200 | Train: Loss=1.3078, F1 Score=0.3654 | Val: Loss=1.3055, F1 Score=0.3643
# Epoch   3/200 | Train: Loss=1.3043, F1 Score=0.3646 | Val: Loss=1.3053, F1 Score=0.3543
# Epoch   4/200 | Train: Loss=1.3009, F1 Score=0.3713 | Val: Loss=1.2992, F1 Score=0.3828
# Epoch   5/200 | Train: Loss=1.2980, F1 Score=0.3828 | Val: Loss=1.3127, F1 Score=0.3534
# Epoch   6/200 | Train: Loss=1.2959, F1 Score=0.3894 | Val: Loss=1.2975, F1 Score=0.3845
# Epoch   7/200 | Train: Loss=1.2955, F1 Score=0.3869 | Val: Loss=1.2965, F1 Score=0.3695
# Epoch   8/200 | Train: Loss=1.2928, F1 Score=0.3938 | Val: Loss=1.2857, F1 Score=0.3936
# Epoch   9/200 | Train: Loss=1.2919, F1 Score=0.3969 | Val: Loss=1.3006, F1 Score=0.3636
# Epoch  10/200 | Train: Loss=1.2891, F1 Score=0.3954 | Val: Loss=1.3140, F1 Score=0.3576
# Epoch  11/200 | Train: Loss=1.2869, F1 Score=0.4036 | Val: Loss=1.2855, F1 Score=0.4045
# Epoch  12/200 | Train: Loss=1.2901, F1 Score=0.4009 | Val: Loss=1.3081, F1 Score=0.3632
# Epoch  13/200 | Train: Loss=1.2874, F1 Score=0.4058 | Val: Loss=1.2757, F1 Score=0.4217
# Epoch  14/200 | Train: Loss=1.2856, F1 Score=0.4030 | Val: Loss=1.2744, F1 Score=0.4282
# Epoch  15/200 | Train: Loss=1.2818, F1 Score=0.4190 | Val: Loss=1.2830, F1 Score=0.4004
# Epoch  16/200 | Train: Loss=1.2820, F1 Score=0.4109 | Val: Loss=1.2777, F1 Score=0.4273
# Epoch  17/200 | Train: Loss=1.2818, F1 Score=0.4148 | Val: Loss=1.2794, F1 Score=0.4179
# Epoch  18/200 | Train: Loss=1.2775, F1 Score=0.4268 | Val: Loss=1.2707, F1 Score=0.4246
# Epoch  19/200 | Train: Loss=1.2822, F1 Score=0.4150 | Val: Loss=1.2926, F1 Score=0.3869
# Epoch  20/200 | Train: Loss=1.2777, F1 Score=0.4194 | Val: Loss=1.2816, F1 Score=0.4075
# Epoch  21/200 | Train: Loss=1.2785, F1 Score=0.4196 | Val: Loss=1.2700, F1 Score=0.4240
# Epoch  22/200 | Train: Loss=1.2721, F1 Score=0.4370 | Val: Loss=1.2678, F1 Score=0.4372
# Epoch  23/200 | Train: Loss=1.2778, F1 Score=0.4216 | Val: Loss=1.2695, F1 Score=0.4459
# Epoch  24/200 | Train: Loss=1.2755, F1 Score=0.4278 | Val: Loss=1.2768, F1 Score=0.4203
# Epoch  25/200 | Train: Loss=1.2713, F1 Score=0.4333 | Val: Loss=1.2738, F1 Score=0.4328
# Epoch  26/200 | Train: Loss=1.2722, F1 Score=0.4311 | Val: Loss=1.3000, F1 Score=0.3732
# Epoch  27/200 | Train: Loss=1.2737, F1 Score=0.4274 | Val: Loss=1.2796, F1 Score=0.4052
# Epoch  28/200 | Train: Loss=1.2678, F1 Score=0.4405 | Val: Loss=1.2731, F1 Score=0.4121
# Epoch  29/200 | Train: Loss=1.2707, F1 Score=0.4386 | Val: Loss=1.2638, F1 Score=0.4473
# Epoch  30/200 | Train: Loss=1.2710, F1 Score=0.4344 | Val: Loss=1.2595, F1 Score=0.4496
# Epoch  31/200 | Train: Loss=1.2643, F1 Score=0.4463 | Val: Loss=1.2782, F1 Score=0.4152
# Epoch  32/200 | Train: Loss=1.2651, F1 Score=0.4447 | Val: Loss=1.2703, F1 Score=0.4341
# Epoch  33/200 | Train: Loss=1.2671, F1 Score=0.4426 | Val: Loss=1.2868, F1 Score=0.4124
# Epoch  34/200 | Train: Loss=1.2697, F1 Score=0.4395 | Val: Loss=1.2692, F1 Score=0.4419
# Epoch  35/200 | Train: Loss=1.2662, F1 Score=0.4404 | Val: Loss=1.2593, F1 Score=0.4352
# Epoch  36/200 | Train: Loss=1.2606, F1 Score=0.4488 | Val: Loss=1.2740, F1 Score=0.4224
# Epoch  37/200 | Train: Loss=1.2625, F1 Score=0.4508 | Val: Loss=1.2832, F1 Score=0.4009
# Epoch  38/200 | Train: Loss=1.2637, F1 Score=0.4524 | Val: Loss=1.2814, F1 Score=0.4126
# Epoch  39/200 | Train: Loss=1.2593, F1 Score=0.4562 | Val: Loss=1.2732, F1 Score=0.4225
# Epoch  40/200 | Train: Loss=1.2618, F1 Score=0.4504 | Val: Loss=1.2724, F1 Score=0.4302
# Epoch  41/200 | Train: Loss=1.2634, F1 Score=0.4446 | Val: Loss=1.2568, F1 Score=0.4475
# Epoch  42/200 | Train: Loss=1.2604, F1 Score=0.4504 | Val: Loss=1.2614, F1 Score=0.4467
# Epoch  43/200 | Train: Loss=1.2593, F1 Score=0.4531 | Val: Loss=1.2837, F1 Score=0.4181
# Epoch  44/200 | Train: Loss=1.2589, F1 Score=0.4521 | Val: Loss=1.2547, F1 Score=0.4376
# Epoch  45/200 | Train: Loss=1.2569, F1 Score=0.4582 | Val: Loss=1.2579, F1 Score=0.4504
# Epoch  46/200 | Train: Loss=1.2539, F1 Score=0.4568 | Val: Loss=1.2627, F1 Score=0.4496
# Epoch  47/200 | Train: Loss=1.2583, F1 Score=0.4533 | Val: Loss=1.3168, F1 Score=0.3529
# Epoch  48/200 | Train: Loss=1.2564, F1 Score=0.4557 | Val: Loss=1.2561, F1 Score=0.4509
# Epoch  49/200 | Train: Loss=1.2546, F1 Score=0.4601 | Val: Loss=1.2668, F1 Score=0.4348
# Epoch  50/200 | Train: Loss=1.2531, F1 Score=0.4577 | Val: Loss=1.2609, F1 Score=0.4497
# Epoch  51/200 | Train: Loss=1.2551, F1 Score=0.4600 | Val: Loss=1.2567, F1 Score=0.4496
# Epoch  52/200 | Train: Loss=1.2520, F1 Score=0.4654 | Val: Loss=1.2609, F1 Score=0.4486
# Epoch  53/200 | Train: Loss=1.2567, F1 Score=0.4577 | Val: Loss=1.2666, F1 Score=0.4241
# Epoch  54/200 | Train: Loss=1.2513, F1 Score=0.4611 | Val: Loss=1.2805, F1 Score=0.4045
# Epoch  55/200 | Train: Loss=1.2460, F1 Score=0.4730 | Val: Loss=1.2634, F1 Score=0.4426
# Epoch  56/200 | Train: Loss=1.2492, F1 Score=0.4681 | Val: Loss=1.2534, F1 Score=0.4591
# Epoch  57/200 | Train: Loss=1.2477, F1 Score=0.4671 | Val: Loss=1.2621, F1 Score=0.4293
# Epoch  58/200 | Train: Loss=1.2445, F1 Score=0.4721 | Val: Loss=1.2617, F1 Score=0.4440
# Epoch  59/200 | Train: Loss=1.2498, F1 Score=0.4635 | Val: Loss=1.2494, F1 Score=0.4723
# Epoch  60/200 | Train: Loss=1.2485, F1 Score=0.4634 | Val: Loss=1.2546, F1 Score=0.4561
# Epoch  61/200 | Train: Loss=1.2470, F1 Score=0.4653 | Val: Loss=1.2590, F1 Score=0.4441
# Epoch  62/200 | Train: Loss=1.2443, F1 Score=0.4729 | Val: Loss=1.2497, F1 Score=0.4454
# Epoch  63/200 | Train: Loss=1.2453, F1 Score=0.4682 | Val: Loss=1.2744, F1 Score=0.4209
# Epoch  64/200 | Train: Loss=1.2475, F1 Score=0.4704 | Val: Loss=1.2591, F1 Score=0.4369
# Epoch  65/200 | Train: Loss=1.2428, F1 Score=0.4791 | Val: Loss=1.2500, F1 Score=0.4462
# Epoch  66/200 | Train: Loss=1.2400, F1 Score=0.4829 | Val: Loss=1.2472, F1 Score=0.4487
# Epoch  67/200 | Train: Loss=1.2401, F1 Score=0.4784 | Val: Loss=1.2552, F1 Score=0.4471
# Epoch  68/200 | Train: Loss=1.2367, F1 Score=0.4820 | Val: Loss=1.2422, F1 Score=0.4696
# Epoch  69/200 | Train: Loss=1.2406, F1 Score=0.4783 | Val: Loss=1.2449, F1 Score=0.4598
# Epoch  70/200 | Train: Loss=1.2415, F1 Score=0.4753 | Val: Loss=1.2554, F1 Score=0.4443
# Epoch  71/200 | Train: Loss=1.2373, F1 Score=0.4841 | Val: Loss=1.2430, F1 Score=0.4673
# Epoch  72/200 | Train: Loss=1.2390, F1 Score=0.4799 | Val: Loss=1.2527, F1 Score=0.4643
# Epoch  73/200 | Train: Loss=1.2391, F1 Score=0.4813 | Val: Loss=1.2451, F1 Score=0.4633
# Epoch  74/200 | Train: Loss=1.2353, F1 Score=0.4877 | Val: Loss=1.2453, F1 Score=0.4634
# Epoch  75/200 | Train: Loss=1.2377, F1 Score=0.4862 | Val: Loss=1.2422, F1 Score=0.4692
# Epoch  76/200 | Train: Loss=1.2359, F1 Score=0.4819 | Val: Loss=1.2526, F1 Score=0.4675
# Epoch  77/200 | Train: Loss=1.2360, F1 Score=0.4826 | Val: Loss=1.2556, F1 Score=0.4637
# Epoch  78/200 | Train: Loss=1.2357, F1 Score=0.4839 | Val: Loss=1.2537, F1 Score=0.4558
# Epoch  79/200 | Train: Loss=1.2313, F1 Score=0.4891 | Val: Loss=1.2486, F1 Score=0.4638
# Epoch  80/200 | Train: Loss=1.2325, F1 Score=0.4901 | Val: Loss=1.2408, F1 Score=0.4783
# Epoch  81/200 | Train: Loss=1.2292, F1 Score=0.4954 | Val: Loss=1.2430, F1 Score=0.4648
# Epoch  82/200 | Train: Loss=1.2314, F1 Score=0.4933 | Val: Loss=1.2489, F1 Score=0.4616
# Epoch  83/200 | Train: Loss=1.2349, F1 Score=0.4924 | Val: Loss=1.2633, F1 Score=0.4406
# Epoch  84/200 | Train: Loss=1.2303, F1 Score=0.4933 | Val: Loss=1.2386, F1 Score=0.4787
# Epoch  85/200 | Train: Loss=1.2286, F1 Score=0.4952 | Val: Loss=1.2447, F1 Score=0.4641
# Epoch  86/200 | Train: Loss=1.2308, F1 Score=0.4916 | Val: Loss=1.2446, F1 Score=0.4600
# Epoch  87/200 | Train: Loss=1.2290, F1 Score=0.4982 | Val: Loss=1.2381, F1 Score=0.4754
# Epoch  88/200 | Train: Loss=1.2285, F1 Score=0.4935 | Val: Loss=1.2401, F1 Score=0.4812
# Epoch  89/200 | Train: Loss=1.2293, F1 Score=0.4931 | Val: Loss=1.2446, F1 Score=0.4648
# Epoch  90/200 | Train: Loss=1.2258, F1 Score=0.4987 | Val: Loss=1.2517, F1 Score=0.4407
# Epoch  91/200 | Train: Loss=1.2279, F1 Score=0.4972 | Val: Loss=1.2388, F1 Score=0.4774
# Epoch  92/200 | Train: Loss=1.2238, F1 Score=0.5032 | Val: Loss=1.2404, F1 Score=0.4758
# Epoch  93/200 | Train: Loss=1.2245, F1 Score=0.5029 | Val: Loss=1.2433, F1 Score=0.4663
# Epoch  94/200 | Train: Loss=1.2265, F1 Score=0.5012 | Val: Loss=1.2304, F1 Score=0.4877
# Epoch  95/200 | Train: Loss=1.2276, F1 Score=0.4946 | Val: Loss=1.2625, F1 Score=0.4348
# Epoch  96/200 | Train: Loss=1.2274, F1 Score=0.5032 | Val: Loss=1.2446, F1 Score=0.4636
# Epoch  97/200 | Train: Loss=1.2248, F1 Score=0.5058 | Val: Loss=1.2430, F1 Score=0.4717
# Epoch  98/200 | Train: Loss=1.2288, F1 Score=0.4979 | Val: Loss=1.2319, F1 Score=0.4945
# Epoch  99/200 | Train: Loss=1.2221, F1 Score=0.5062 | Val: Loss=1.2344, F1 Score=0.4861
# Epoch 100/200 | Train: Loss=1.2206, F1 Score=0.5107 | Val: Loss=1.2401, F1 Score=0.4742
# Epoch 101/200 | Train: Loss=1.2219, F1 Score=0.5113 | Val: Loss=1.2414, F1 Score=0.4772
# Epoch 102/200 | Train: Loss=1.2189, F1 Score=0.5129 | Val: Loss=1.2485, F1 Score=0.4592
# Epoch 103/200 | Train: Loss=1.2219, F1 Score=0.5045 | Val: Loss=1.2343, F1 Score=0.4913
# Epoch 104/200 | Train: Loss=1.2168, F1 Score=0.5131 | Val: Loss=1.2314, F1 Score=0.4872
# Epoch 105/200 | Train: Loss=1.2199, F1 Score=0.5104 | Val: Loss=1.2219, F1 Score=0.4987
# Epoch 106/200 | Train: Loss=1.2162, F1 Score=0.5169 | Val: Loss=1.2349, F1 Score=0.4878
# Epoch 107/200 | Train: Loss=1.2191, F1 Score=0.5090 | Val: Loss=1.2239, F1 Score=0.5011
# Epoch 108/200 | Train: Loss=1.2171, F1 Score=0.5099 | Val: Loss=1.2423, F1 Score=0.4725
# Epoch 109/200 | Train: Loss=1.2167, F1 Score=0.5136 | Val: Loss=1.2170, F1 Score=0.5067
# Epoch 110/200 | Train: Loss=1.2218, F1 Score=0.5067 | Val: Loss=1.2288, F1 Score=0.4897
# Epoch 111/200 | Train: Loss=1.2166, F1 Score=0.5141 | Val: Loss=1.2342, F1 Score=0.4899
# Epoch 112/200 | Train: Loss=1.2198, F1 Score=0.5052 | Val: Loss=1.2611, F1 Score=0.4461
# Epoch 113/200 | Train: Loss=1.2155, F1 Score=0.5174 | Val: Loss=1.2321, F1 Score=0.4838
# Epoch 114/200 | Train: Loss=1.2159, F1 Score=0.5154 | Val: Loss=1.2296, F1 Score=0.4779
# Epoch 115/200 | Train: Loss=1.2165, F1 Score=0.5151 | Val: Loss=1.2306, F1 Score=0.4825
# Epoch 116/200 | Train: Loss=1.2155, F1 Score=0.5149 | Val: Loss=1.2283, F1 Score=0.4944
# Epoch 117/200 | Train: Loss=1.2118, F1 Score=0.5195 | Val: Loss=1.2334, F1 Score=0.4855
# Epoch 118/200 | Train: Loss=1.2121, F1 Score=0.5219 | Val: Loss=1.2250, F1 Score=0.4881
# Epoch 119/200 | Train: Loss=1.2085, F1 Score=0.5237 | Val: Loss=1.2255, F1 Score=0.5081
# Epoch 120/200 | Train: Loss=1.2138, F1 Score=0.5241 | Val: Loss=1.2349, F1 Score=0.4830
# Epoch 121/200 | Train: Loss=1.2111, F1 Score=0.5195 | Val: Loss=1.2340, F1 Score=0.4699
# Epoch 122/200 | Train: Loss=1.2072, F1 Score=0.5291 | Val: Loss=1.2259, F1 Score=0.5151
# Epoch 123/200 | Train: Loss=1.2101, F1 Score=0.5253 | Val: Loss=1.2289, F1 Score=0.4850
# Epoch 124/200 | Train: Loss=1.2081, F1 Score=0.5278 | Val: Loss=1.2437, F1 Score=0.4761
# Epoch 125/200 | Train: Loss=1.2080, F1 Score=0.5287 | Val: Loss=1.2251, F1 Score=0.4916
# Epoch 126/200 | Train: Loss=1.2108, F1 Score=0.5202 | Val: Loss=1.2331, F1 Score=0.4892
# Epoch 127/200 | Train: Loss=1.2098, F1 Score=0.5239 | Val: Loss=1.2300, F1 Score=0.4910
# Epoch 128/200 | Train: Loss=1.2077, F1 Score=0.5291 | Val: Loss=1.2254, F1 Score=0.4903
# Epoch 129/200 | Train: Loss=1.2057, F1 Score=0.5290 | Val: Loss=1.2226, F1 Score=0.5114
# Epoch 130/200 | Train: Loss=1.2080, F1 Score=0.5239 | Val: Loss=1.2243, F1 Score=0.4770
# Epoch 131/200 | Train: Loss=1.2070, F1 Score=0.5263 | Val: Loss=1.2255, F1 Score=0.4930
# Epoch 132/200 | Train: Loss=1.2053, F1 Score=0.5281 | Val: Loss=1.2248, F1 Score=0.4856
# Epoch 133/200 | Train: Loss=1.2076, F1 Score=0.5211 | Val: Loss=1.2243, F1 Score=0.4944
# Epoch 134/200 | Train: Loss=1.2048, F1 Score=0.5255 | Val: Loss=1.2344, F1 Score=0.4853
# Epoch 135/200 | Train: Loss=1.2052, F1 Score=0.5362 | Val: Loss=1.2327, F1 Score=0.4823
# Epoch 136/200 | Train: Loss=1.2030, F1 Score=0.5316 | Val: Loss=1.2194, F1 Score=0.5026
# Epoch 137/200 | Train: Loss=1.2091, F1 Score=0.5229 | Val: Loss=1.2252, F1 Score=0.4912
# Epoch 138/200 | Train: Loss=1.2054, F1 Score=0.5293 | Val: Loss=1.2208, F1 Score=0.4978
# Epoch 139/200 | Train: Loss=1.2056, F1 Score=0.5329 | Val: Loss=1.2200, F1 Score=0.5017
# Epoch 140/200 | Train: Loss=1.2020, F1 Score=0.5339 | Val: Loss=1.2324, F1 Score=0.4833
# Epoch 141/200 | Train: Loss=1.2011, F1 Score=0.5365 | Val: Loss=1.2248, F1 Score=0.4797
# Epoch 142/200 | Train: Loss=1.1998, F1 Score=0.5413 | Val: Loss=1.2172, F1 Score=0.5018
# Epoch 143/200 | Train: Loss=1.2018, F1 Score=0.5298 | Val: Loss=1.2252, F1 Score=0.4864
# Epoch 144/200 | Train: Loss=1.2062, F1 Score=0.5256 | Val: Loss=1.2190, F1 Score=0.5103
# Epoch 145/200 | Train: Loss=1.1987, F1 Score=0.5367 | Val: Loss=1.2176, F1 Score=0.5116
# Epoch 146/200 | Train: Loss=1.1976, F1 Score=0.5413 | Val: Loss=1.2177, F1 Score=0.5120
# Epoch 147/200 | Train: Loss=1.1990, F1 Score=0.5371 | Val: Loss=1.2216, F1 Score=0.5050
# Epoch 148/200 | Train: Loss=1.1990, F1 Score=0.5349 | Val: Loss=1.2208, F1 Score=0.5076
# Epoch 149/200 | Train: Loss=1.2023, F1 Score=0.5310 | Val: Loss=1.2240, F1 Score=0.4930
# Epoch 150/200 | Train: Loss=1.1988, F1 Score=0.5375 | Val: Loss=1.2189, F1 Score=0.5015
# Epoch 151/200 | Train: Loss=1.2040, F1 Score=0.5302 | Val: Loss=1.2189, F1 Score=0.5049
# Epoch 152/200 | Train: Loss=1.1972, F1 Score=0.5385 | Val: Loss=1.2227, F1 Score=0.4981
# Epoch 153/200 | Train: Loss=1.2024, F1 Score=0.5316 | Val: Loss=1.2173, F1 Score=0.5043
# Epoch 154/200 | Train: Loss=1.1989, F1 Score=0.5388 | Val: Loss=1.2251, F1 Score=0.5039
# Epoch 155/200 | Train: Loss=1.1974, F1 Score=0.5434 | Val: Loss=1.2217, F1 Score=0.4899
# Epoch 156/200 | Train: Loss=1.2019, F1 Score=0.5349 | Val: Loss=1.2202, F1 Score=0.5148
# Epoch 157/200 | Train: Loss=1.1995, F1 Score=0.5341 | Val: Loss=1.2187, F1 Score=0.5054
# Epoch 158/200 | Train: Loss=1.1997, F1 Score=0.5356 | Val: Loss=1.2140, F1 Score=0.5105
# Epoch 159/200 | Train: Loss=1.1952, F1 Score=0.5443 | Val: Loss=1.2180, F1 Score=0.5042
# Epoch 160/200 | Train: Loss=1.1986, F1 Score=0.5393 | Val: Loss=1.2216, F1 Score=0.5004
# Epoch 161/200 | Train: Loss=1.1937, F1 Score=0.5487 | Val: Loss=1.2226, F1 Score=0.5090
# Epoch 162/200 | Train: Loss=1.1956, F1 Score=0.5428 | Val: Loss=1.2169, F1 Score=0.5156
# Epoch 163/200 | Train: Loss=1.1934, F1 Score=0.5437 | Val: Loss=1.2197, F1 Score=0.5004
# Epoch 164/200 | Train: Loss=1.1973, F1 Score=0.5372 | Val: Loss=1.2216, F1 Score=0.5075
# Epoch 165/200 | Train: Loss=1.1950, F1 Score=0.5426 | Val: Loss=1.2164, F1 Score=0.5143
# Epoch 166/200 | Train: Loss=1.2014, F1 Score=0.5367 | Val: Loss=1.2190, F1 Score=0.4989
# Epoch 167/200 | Train: Loss=1.1943, F1 Score=0.5479 | Val: Loss=1.2157, F1 Score=0.5117
# Epoch 168/200 | Train: Loss=1.1980, F1 Score=0.5411 | Val: Loss=1.2191, F1 Score=0.5042
# Epoch 169/200 | Train: Loss=1.1962, F1 Score=0.5437 | Val: Loss=1.2180, F1 Score=0.5102
# Epoch 170/200 | Train: Loss=1.1956, F1 Score=0.5468 | Val: Loss=1.2152, F1 Score=0.5227
# Epoch 171/200 | Train: Loss=1.1953, F1 Score=0.5442 | Val: Loss=1.2177, F1 Score=0.5132
# Epoch 172/200 | Train: Loss=1.1954, F1 Score=0.5468 | Val: Loss=1.2133, F1 Score=0.5125
# Epoch 173/200 | Train: Loss=1.1945, F1 Score=0.5448 | Val: Loss=1.2173, F1 Score=0.5197
# Epoch 174/200 | Train: Loss=1.1946, F1 Score=0.5429 | Val: Loss=1.2149, F1 Score=0.5196
# Epoch 175/200 | Train: Loss=1.1962, F1 Score=0.5431 | Val: Loss=1.2191, F1 Score=0.5092
# Epoch 176/200 | Train: Loss=1.1964, F1 Score=0.5410 | Val: Loss=1.2178, F1 Score=0.5140
# Epoch 177/200 | Train: Loss=1.1946, F1 Score=0.5468 | Val: Loss=1.2171, F1 Score=0.5120
# Epoch 178/200 | Train: Loss=1.1939, F1 Score=0.5429 | Val: Loss=1.2180, F1 Score=0.5134
# Epoch 179/200 | Train: Loss=1.1919, F1 Score=0.5474 | Val: Loss=1.2171, F1 Score=0.5096
# Epoch 180/200 | Train: Loss=1.1941, F1 Score=0.5439 | Val: Loss=1.2169, F1 Score=0.5118
# Epoch 181/200 | Train: Loss=1.1986, F1 Score=0.5402 | Val: Loss=1.2173, F1 Score=0.5130
# Epoch 182/200 | Train: Loss=1.1897, F1 Score=0.5533 | Val: Loss=1.2175, F1 Score=0.5174
# Epoch 183/200 | Train: Loss=1.1972, F1 Score=0.5393 | Val: Loss=1.2197, F1 Score=0.5028
# Epoch 184/200 | Train: Loss=1.1921, F1 Score=0.5471 | Val: Loss=1.2176, F1 Score=0.5106
# Epoch 185/200 | Train: Loss=1.1928, F1 Score=0.5463 | Val: Loss=1.2171, F1 Score=0.5214
# Epoch 186/200 | Train: Loss=1.1960, F1 Score=0.5378 | Val: Loss=1.2173, F1 Score=0.5157
# Epoch 187/200 | Train: Loss=1.1902, F1 Score=0.5515 | Val: Loss=1.2154, F1 Score=0.5228
# Epoch 188/200 | Train: Loss=1.1934, F1 Score=0.5492 | Val: Loss=1.2158, F1 Score=0.5089
# Epoch 189/200 | Train: Loss=1.1920, F1 Score=0.5482 | Val: Loss=1.2179, F1 Score=0.5083
# Epoch 190/200 | Train: Loss=1.1927, F1 Score=0.5462 | Val: Loss=1.2153, F1 Score=0.5185
# Epoch 191/200 | Train: Loss=1.1893, F1 Score=0.5524 | Val: Loss=1.2135, F1 Score=0.5164
# Epoch 192/200 | Train: Loss=1.1909, F1 Score=0.5477 | Val: Loss=1.2156, F1 Score=0.5130
# Epoch 193/200 | Train: Loss=1.1917, F1 Score=0.5483 | Val: Loss=1.2165, F1 Score=0.5132
# Epoch 194/200 | Train: Loss=1.1947, F1 Score=0.5473 | Val: Loss=1.2156, F1 Score=0.5165
# Epoch 195/200 | Train: Loss=1.1887, F1 Score=0.5552 | Val: Loss=1.2164, F1 Score=0.5153
# Epoch 196/200 | Train: Loss=1.1903, F1 Score=0.5515 | Val: Loss=1.2153, F1 Score=0.5245
# Epoch 197/200 | Train: Loss=1.1892, F1 Score=0.5534 | Val: Loss=1.2136, F1 Score=0.5307
# Epoch 198/200 | Train: Loss=1.1900, F1 Score=0.5492 | Val: Loss=1.2132, F1 Score=0.5181
# Epoch 199/200 | Train: Loss=1.1923, F1 Score=0.5480 | Val: Loss=1.2152, F1 Score=0.5178
# Epoch 200/200 | Train: Loss=1.1937, F1 Score=0.5451 | Val: Loss=1.2154, F1 Score=0.5163
# Best model restored from epoch 197 with val_f1 0.5307

# %% [markdown]
# ## Evaluation

# %%
# @title Plot Hitory
# Create a figure with two side-by-side subplots (two columns)
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(18, 5))

# Plot of training and validation loss on the first axis
ax1.plot(training_history['train_loss'], label='Training loss', alpha=0.3, color='#ff7f0e', linestyle='--')
ax1.plot(training_history['val_loss'], label='Validation loss', alpha=0.9, color='#ff7f0e')
ax1.set_title('Loss')
ax1.legend()
ax1.grid(alpha=0.3)

# Plot of training and validation accuracy on the second axis
ax2.plot(training_history['train_f1'], label='Training f1', alpha=0.3, color='#ff7f0e', linestyle='--')
ax2.plot(training_history['val_f1'], label='Validation f1', alpha=0.9, color='#ff7f0e')
ax2.set_title('F1 Score')
ax2.legend()
ax2.grid(alpha=0.3)

# Adjust the layout and display the plot
plt.tight_layout()
plt.subplots_adjust(right=0.85)
plt.show()

# %%
# @title Plot Confusion Matrix
# Collect predictions and ground truth labels
val_preds, val_targets = [], []
with torch.no_grad():  # Disable gradient computation for inference
    for xb, yb in val_loader:
        xb = xb.to(device)
        # Permute dimensions from (batch_size, height, width, channels) to (batch_size, channels, height, width)
        # This line is now redundant and incorrect as data is already (Batch, Channels, Height, Width)
        # xb = xb.permute(0, 3, 1, 2)

        # Forward pass: get model predictions
        logits = inception_model(xb)
        preds = logits.argmax(dim=1).cpu().numpy()

        # Store batch results
        val_preds.append(preds)
        val_targets.append(yb.numpy())

# Combine all batches into single arrays
val_preds = np.concatenate(val_preds)
val_targets = np.concatenate(val_targets)

# Calculate overall validation metrics
val_acc = accuracy_score(val_targets, val_preds)
val_prec = precision_score(val_targets, val_preds, average='weighted')
val_rec = recall_score(val_targets, val_preds, average='weighted')
val_f1 = f1_score(val_targets, val_preds, average='weighted')
print(f"Accuracy over the validation set: {val_acc:.4f}")
print(f"Precision over the validation set: {val_prec:.4f}")
print(f"Recall over the validation set: {val_rec:.4f}")
print(f"F1 score over the validation set: {val_f1:.4f}")

# Generate confusion matrix for detailed error analysis
cm = confusion_matrix(val_targets, val_preds)

# Create numeric labels for heatmap annotation
labels = np.array([f"{num}" for num in cm.flatten()]).reshape(cm.shape)

# Visualise confusion matrix
plt.figure(figsize=(8, 7))
sns.heatmap(cm, annot=labels, fmt='',
            cmap='Blues')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix — Validation Set')
plt.tight_layout()
plt.show()
# Out:
# Accuracy over the validation set: 0.5525
# Precision over the validation set: 0.5730
# Recall over the validation set: 0.5525
# F1 score over the validation set: 0.5271

# %% [markdown]
# ## Hyperparameter Tuning

# %%
# ----------------------------
# Hyperparameter search space
# ----------------------------

def grid_search(
    param_grid,
    input_shape,
    num_classes,
    train_loader,
    val_loader,
    criterion,
    device,
    base_config=None,
    max_epochs=100,
    patience=15,
    weight_decay=0.0,
    verbose=1,
    save_path="models/best_cnn_grid_search.pt"
):
    """
    Performs grid search over hyperparameters for the CNN model.

    param_grid: dict of lists
    base_config: optional dictionary of CNN parameters to keep fixed
    """

    import itertools
    import copy

    # Expand hyperparameter grid
    all_configs = list(itertools.product(*param_grid.values()))
    print(f"\nTotal configurations: {len(all_configs)}\n")

    results = []
    best_score = -float("inf")
    best_params = None
    best_model_state = None

    # Training loop over all combinations
    for config in all_configs:
        hparams = dict(zip(param_grid.keys(), config))

        # Merge with fixed parameters (if provided)
        if base_config:
            full_params = {**base_config, **hparams}
        else:
            full_params = hparams

        print("\n========================================")
        print("Testing configuration:", full_params)
        print("========================================")


        # Build model using supplied parameters
        model = InceptionModel(
            input_shape=input_shape,
            output_shape=num_classes,
            num_blocks=full_params["num_blocks"],
            stack=full_params["stack"],
            initial_channels=full_params["initial_channels"],
            channel_multiplier=full_params["channel_multiplier"],
            dropout_rate=full_params["dropout_rate"],
            use_stride=full_params["use_stride"],
            stride_value=full_params["stride_value"],
            padding_size=full_params["padding_size"],
            pool_size=full_params["pool_size"],
        ).to(device)
        # Optimizer
        optimizer = torch.optim.AdamW(
            model.parameters(),
            lr=full_params["lr"],
            weight_decay=weight_decay
        )

        # AMP scaler
        scaler = torch.amp.GradScaler(enabled=(device.type == 'cuda'))

        # Train model
        model, history = fit(
            model=model,
            train_loader=train_loader,
            val_loader=val_loader,
            epochs=max_epochs,
            criterion=criterion,
            optimizer=optimizer,
            scaler=scaler,
            scheduler=scheduler,
            device=device,
            patience=patience,
            experiment_name="grid_temp",
            verbose=0,
        )

        # Score to compare models
        val_f1 = np.max(history["val_f1"])
        print(f" → F1 Score: {val_f1:.4f}")

        # Save results
        row = full_params.copy()
        row["val_f1"] = val_f1
        results.append(row)

        # Track best model
        if val_f1 > best_score:
            best_score = val_f1
            best_params = full_params.copy()
            best_model_state = copy.deepcopy(model.state_dict())

        # Free GPU memory
        del model
        torch.cuda.empty_cache()

    # Save best model
    torch.save(best_model_state, save_path)

    print("\n========================")
    print("Best hyperparameters:")
    print(best_params)
    print("Best F1:", best_score)
    print("========================")

    # Return results as DataFrame
    return pd.DataFrame(results), best_params, best_score

# %%
param_grid = {
    "num_blocks":        [1, 2, 3],
    "stack":   [1, 2],
    "initial_channels":  [16, 32],
    "channel_multiplier":[2],
    "dropout_rate":      [0.0, 0.2, 0.4],
    "lr":                [1e-3, 5e-4, 1e-4],
}

# Fixed parameters (architecture options you don't want to grid-search)
base_config = {
    "use_stride": USE_STRIDE,
    "stride_value": STRIDE_VALUE,
    "padding_size": PADDING_SIZE,
    "pool_size": POOL_SIZE,
}

df_results, best_params, best_score = grid_search(
    param_grid=param_grid,
    input_shape=input_shape,
    num_classes=num_classes,
    train_loader=train_loader,
    val_loader=val_loader,
    criterion=criterion,
    device=device,
    base_config=base_config,
    weight_decay=L2_LAMBDA,
    max_epochs=100,
    patience=15,
    save_path="models/best_cnn_grid_search.pt"
)
# Out:
# Total configurations: 108
#
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 1, 'stack': 1, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.0, 'lr': 0.001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 47 epochs.
# Best model restored from epoch 32 with val_f1 0.2633
#  → F1 Score: 0.2633
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 1, 'stack': 1, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.0, 'lr': 0.0005}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 26 epochs.
# Best model restored from epoch 11 with val_f1 0.2952
#  → F1 Score: 0.2952
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 1, 'stack': 1, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.0, 'lr': 0.0001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 18 epochs.
# Best model restored from epoch 3 with val_f1 0.2722
#  → F1 Score: 0.2722
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 1, 'stack': 1, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.2, 'lr': 0.001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 16 epochs.
# Best model restored from epoch 1 with val_f1 0.1503
#  → F1 Score: 0.1503
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 1, 'stack': 1, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.2, 'lr': 0.0005}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 54 epochs.
# Best model restored from epoch 39 with val_f1 0.3076
#  → F1 Score: 0.3076
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 1, 'stack': 1, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.2, 'lr': 0.0001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 38 epochs.
# Best model restored from epoch 23 with val_f1 0.1953
#  → F1 Score: 0.1953
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 1, 'stack': 1, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.4, 'lr': 0.001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 20 epochs.
# Best model restored from epoch 5 with val_f1 0.2347
#  → F1 Score: 0.2347
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 1, 'stack': 1, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.4, 'lr': 0.0005}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 20 epochs.
# Best model restored from epoch 5 with val_f1 0.2297
#  → F1 Score: 0.2297
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 1, 'stack': 1, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.4, 'lr': 0.0001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 16 epochs.
# Best model restored from epoch 1 with val_f1 0.1159
#  → F1 Score: 0.1159
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 1, 'stack': 1, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.0, 'lr': 0.001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 51 epochs.
# Best model restored from epoch 36 with val_f1 0.4001
#  → F1 Score: 0.4001
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 1, 'stack': 1, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.0, 'lr': 0.0005}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 23 epochs.
# Best model restored from epoch 8 with val_f1 0.2054
#  → F1 Score: 0.2054
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 1, 'stack': 1, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.0, 'lr': 0.0001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 34 epochs.
# Best model restored from epoch 19 with val_f1 0.2698
#  → F1 Score: 0.2698
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 1, 'stack': 1, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.2, 'lr': 0.001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 29 epochs.
# Best model restored from epoch 14 with val_f1 0.2896
#  → F1 Score: 0.2896
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 1, 'stack': 1, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.2, 'lr': 0.0005}
# ========================================
# Training 100 epochs...
# Best model restored from epoch 96 with val_f1 0.3974
#  → F1 Score: 0.3974
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 1, 'stack': 1, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.2, 'lr': 0.0001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 37 epochs.
# Best model restored from epoch 22 with val_f1 0.2527
#  → F1 Score: 0.2527
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 1, 'stack': 1, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.4, 'lr': 0.001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 26 epochs.
# Best model restored from epoch 11 with val_f1 0.2832
#  → F1 Score: 0.2832
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 1, 'stack': 1, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.4, 'lr': 0.0005}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 16 epochs.
# Best model restored from epoch 1 with val_f1 0.1503
#  → F1 Score: 0.1503
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 1, 'stack': 1, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.4, 'lr': 0.0001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 16 epochs.
# Best model restored from epoch 1 with val_f1 0.1385
#  → F1 Score: 0.1385
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 1, 'stack': 2, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.0, 'lr': 0.001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 65 epochs.
# Best model restored from epoch 50 with val_f1 0.4025
#  → F1 Score: 0.4025
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 1, 'stack': 2, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.0, 'lr': 0.0005}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 39 epochs.
# Best model restored from epoch 24 with val_f1 0.2553
#  → F1 Score: 0.2553
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 1, 'stack': 2, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.0, 'lr': 0.0001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 29 epochs.
# Best model restored from epoch 14 with val_f1 0.3119
#  → F1 Score: 0.3119
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 1, 'stack': 2, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.2, 'lr': 0.001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 36 epochs.
# Best model restored from epoch 21 with val_f1 0.3620
#  → F1 Score: 0.3620
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 1, 'stack': 2, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.2, 'lr': 0.0005}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 38 epochs.
# Best model restored from epoch 23 with val_f1 0.3855
#  → F1 Score: 0.3855
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 1, 'stack': 2, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.2, 'lr': 0.0001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 18 epochs.
# Best model restored from epoch 3 with val_f1 0.1400
#  → F1 Score: 0.1400
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 1, 'stack': 2, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.4, 'lr': 0.001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 55 epochs.
# Best model restored from epoch 40 with val_f1 0.4178
#  → F1 Score: 0.4178
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 1, 'stack': 2, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.4, 'lr': 0.0005}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 20 epochs.
# Best model restored from epoch 5 with val_f1 0.1385
#  → F1 Score: 0.1385
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 1, 'stack': 2, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.4, 'lr': 0.0001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 62 epochs.
# Best model restored from epoch 47 with val_f1 0.3489
#  → F1 Score: 0.3489
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 1, 'stack': 2, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.0, 'lr': 0.001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 28 epochs.
# Best model restored from epoch 13 with val_f1 0.3813
#  → F1 Score: 0.3813
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 1, 'stack': 2, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.0, 'lr': 0.0005}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 32 epochs.
# Best model restored from epoch 17 with val_f1 0.2898
#  → F1 Score: 0.2898
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 1, 'stack': 2, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.0, 'lr': 0.0001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 16 epochs.
# Best model restored from epoch 1 with val_f1 0.1385
#  → F1 Score: 0.1385
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 1, 'stack': 2, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.2, 'lr': 0.001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 40 epochs.
# Best model restored from epoch 25 with val_f1 0.3629
#  → F1 Score: 0.3629
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 1, 'stack': 2, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.2, 'lr': 0.0005}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 47 epochs.
# Best model restored from epoch 32 with val_f1 0.4129
#  → F1 Score: 0.4129
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 1, 'stack': 2, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.2, 'lr': 0.0001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 24 epochs.
# Best model restored from epoch 9 with val_f1 0.3151
#  → F1 Score: 0.3151
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 1, 'stack': 2, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.4, 'lr': 0.001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 36 epochs.
# Best model restored from epoch 21 with val_f1 0.4385
#  → F1 Score: 0.4385
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 1, 'stack': 2, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.4, 'lr': 0.0005}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 37 epochs.
# Best model restored from epoch 22 with val_f1 0.4045
#  → F1 Score: 0.4045
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 1, 'stack': 2, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.4, 'lr': 0.0001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 31 epochs.
# Best model restored from epoch 16 with val_f1 0.2794
#  → F1 Score: 0.2794
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 2, 'stack': 1, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.0, 'lr': 0.001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 56 epochs.
# Best model restored from epoch 41 with val_f1 0.5022
#  → F1 Score: 0.5022
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 2, 'stack': 1, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.0, 'lr': 0.0005}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 50 epochs.
# Best model restored from epoch 35 with val_f1 0.2979
#  → F1 Score: 0.2979
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 2, 'stack': 1, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.0, 'lr': 0.0001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 16 epochs.
# Best model restored from epoch 1 with val_f1 0.1159
#  → F1 Score: 0.1159
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 2, 'stack': 1, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.2, 'lr': 0.001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 79 epochs.
# Best model restored from epoch 64 with val_f1 0.4471
#  → F1 Score: 0.4471
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 2, 'stack': 1, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.2, 'lr': 0.0005}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 29 epochs.
# Best model restored from epoch 14 with val_f1 0.2772
#  → F1 Score: 0.2772
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 2, 'stack': 1, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.2, 'lr': 0.0001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 89 epochs.
# Best model restored from epoch 74 with val_f1 0.3638
#  → F1 Score: 0.3638
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 2, 'stack': 1, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.4, 'lr': 0.001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 28 epochs.
# Best model restored from epoch 13 with val_f1 0.2553
#  → F1 Score: 0.2553
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 2, 'stack': 1, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.4, 'lr': 0.0005}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 31 epochs.
# Best model restored from epoch 16 with val_f1 0.2723
#  → F1 Score: 0.2723
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 2, 'stack': 1, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.4, 'lr': 0.0001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 16 epochs.
# Best model restored from epoch 1 with val_f1 0.1159
#  → F1 Score: 0.1159
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 2, 'stack': 1, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.0, 'lr': 0.001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 41 epochs.
# Best model restored from epoch 26 with val_f1 0.4226
#  → F1 Score: 0.4226
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 2, 'stack': 1, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.0, 'lr': 0.0005}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 30 epochs.
# Best model restored from epoch 15 with val_f1 0.3682
#  → F1 Score: 0.3682
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 2, 'stack': 1, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.0, 'lr': 0.0001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 43 epochs.
# Best model restored from epoch 28 with val_f1 0.3993
#  → F1 Score: 0.3993
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 2, 'stack': 1, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.2, 'lr': 0.001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 51 epochs.
# Best model restored from epoch 36 with val_f1 0.4125
#  → F1 Score: 0.4125
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 2, 'stack': 1, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.2, 'lr': 0.0005}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 54 epochs.
# Best model restored from epoch 39 with val_f1 0.4321
#  → F1 Score: 0.4321
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 2, 'stack': 1, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.2, 'lr': 0.0001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 22 epochs.
# Best model restored from epoch 7 with val_f1 0.2742
#  → F1 Score: 0.2742
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 2, 'stack': 1, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.4, 'lr': 0.001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 46 epochs.
# Best model restored from epoch 31 with val_f1 0.3974
#  → F1 Score: 0.3974
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 2, 'stack': 1, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.4, 'lr': 0.0005}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 63 epochs.
# Best model restored from epoch 48 with val_f1 0.4121
#  → F1 Score: 0.4121
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 2, 'stack': 1, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.4, 'lr': 0.0001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 29 epochs.
# Best model restored from epoch 14 with val_f1 0.2825
#  → F1 Score: 0.2825
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 2, 'stack': 2, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.0, 'lr': 0.001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 62 epochs.
# Best model restored from epoch 47 with val_f1 0.4272
#  → F1 Score: 0.4272
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 2, 'stack': 2, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.0, 'lr': 0.0005}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 61 epochs.
# Best model restored from epoch 46 with val_f1 0.3571
#  → F1 Score: 0.3571
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 2, 'stack': 2, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.0, 'lr': 0.0001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 29 epochs.
# Best model restored from epoch 14 with val_f1 0.3288
#  → F1 Score: 0.3288
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 2, 'stack': 2, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.2, 'lr': 0.001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 47 epochs.
# Best model restored from epoch 32 with val_f1 0.4317
#  → F1 Score: 0.4317
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 2, 'stack': 2, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.2, 'lr': 0.0005}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 32 epochs.
# Best model restored from epoch 17 with val_f1 0.3175
#  → F1 Score: 0.3175
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 2, 'stack': 2, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.2, 'lr': 0.0001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 87 epochs.
# Best model restored from epoch 72 with val_f1 0.3014
#  → F1 Score: 0.3014
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 2, 'stack': 2, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.4, 'lr': 0.001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 62 epochs.
# Best model restored from epoch 47 with val_f1 0.4637
#  → F1 Score: 0.4637
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 2, 'stack': 2, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.4, 'lr': 0.0005}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 22 epochs.
# Best model restored from epoch 7 with val_f1 0.2644
#  → F1 Score: 0.2644
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 2, 'stack': 2, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.4, 'lr': 0.0001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 64 epochs.
# Best model restored from epoch 49 with val_f1 0.3725
#  → F1 Score: 0.3725
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 2, 'stack': 2, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.0, 'lr': 0.001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 48 epochs.
# Best model restored from epoch 33 with val_f1 0.4043
#  → F1 Score: 0.4043
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 2, 'stack': 2, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.0, 'lr': 0.0005}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 60 epochs.
# Best model restored from epoch 45 with val_f1 0.4484
#  → F1 Score: 0.4484
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 2, 'stack': 2, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.0, 'lr': 0.0001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 21 epochs.
# Best model restored from epoch 6 with val_f1 0.2593
#  → F1 Score: 0.2593
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 2, 'stack': 2, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.2, 'lr': 0.001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 29 epochs.
# Best model restored from epoch 14 with val_f1 0.4238
#  → F1 Score: 0.4238
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 2, 'stack': 2, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.2, 'lr': 0.0005}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 32 epochs.
# Best model restored from epoch 17 with val_f1 0.3786
#  → F1 Score: 0.3786
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 2, 'stack': 2, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.2, 'lr': 0.0001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 53 epochs.
# Best model restored from epoch 38 with val_f1 0.3974
#  → F1 Score: 0.3974
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 2, 'stack': 2, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.4, 'lr': 0.001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 47 epochs.
# Best model restored from epoch 32 with val_f1 0.4800
#  → F1 Score: 0.4800
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 2, 'stack': 2, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.4, 'lr': 0.0005}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 61 epochs.
# Best model restored from epoch 46 with val_f1 0.4645
#  → F1 Score: 0.4645
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 2, 'stack': 2, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.4, 'lr': 0.0001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 34 epochs.
# Best model restored from epoch 19 with val_f1 0.3337
#  → F1 Score: 0.3337
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 3, 'stack': 1, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.0, 'lr': 0.001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 27 epochs.
# Best model restored from epoch 12 with val_f1 0.4612
#  → F1 Score: 0.4612
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 3, 'stack': 1, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.0, 'lr': 0.0005}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 28 epochs.
# Best model restored from epoch 13 with val_f1 0.3985
#  → F1 Score: 0.3985
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 3, 'stack': 1, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.0, 'lr': 0.0001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 45 epochs.
# Best model restored from epoch 30 with val_f1 0.2609
#  → F1 Score: 0.2609
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 3, 'stack': 1, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.2, 'lr': 0.001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 25 epochs.
# Best model restored from epoch 10 with val_f1 0.3920
#  → F1 Score: 0.3920
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 3, 'stack': 1, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.2, 'lr': 0.0005}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 40 epochs.
# Best model restored from epoch 25 with val_f1 0.4035
#  → F1 Score: 0.4035
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 3, 'stack': 1, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.2, 'lr': 0.0001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 28 epochs.
# Best model restored from epoch 13 with val_f1 0.2768
#  → F1 Score: 0.2768
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 3, 'stack': 1, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.4, 'lr': 0.001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 48 epochs.
# Best model restored from epoch 33 with val_f1 0.4610
#  → F1 Score: 0.4610
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 3, 'stack': 1, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.4, 'lr': 0.0005}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 44 epochs.
# Best model restored from epoch 29 with val_f1 0.4232
#  → F1 Score: 0.4232
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 3, 'stack': 1, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.4, 'lr': 0.0001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 39 epochs.
# Best model restored from epoch 24 with val_f1 0.2730
#  → F1 Score: 0.2730
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 3, 'stack': 1, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.0, 'lr': 0.001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 49 epochs.
# Best model restored from epoch 34 with val_f1 0.4151
#  → F1 Score: 0.4151
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 3, 'stack': 1, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.0, 'lr': 0.0005}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 41 epochs.
# Best model restored from epoch 26 with val_f1 0.4237
#  → F1 Score: 0.4237
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 3, 'stack': 1, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.0, 'lr': 0.0001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 67 epochs.
# Best model restored from epoch 52 with val_f1 0.3945
#  → F1 Score: 0.3945
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 3, 'stack': 1, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.2, 'lr': 0.001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 20 epochs.
# Best model restored from epoch 5 with val_f1 0.4017
#  → F1 Score: 0.4017
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 3, 'stack': 1, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.2, 'lr': 0.0005}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 30 epochs.
# Best model restored from epoch 15 with val_f1 0.4258
#  → F1 Score: 0.4258
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 3, 'stack': 1, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.2, 'lr': 0.0001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 59 epochs.
# Best model restored from epoch 44 with val_f1 0.3636
#  → F1 Score: 0.3636
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 3, 'stack': 1, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.4, 'lr': 0.001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 30 epochs.
# Best model restored from epoch 15 with val_f1 0.4175
#  → F1 Score: 0.4175
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 3, 'stack': 1, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.4, 'lr': 0.0005}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 42 epochs.
# Best model restored from epoch 27 with val_f1 0.4378
#  → F1 Score: 0.4378
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 3, 'stack': 1, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.4, 'lr': 0.0001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 30 epochs.
# Best model restored from epoch 15 with val_f1 0.3984
#  → F1 Score: 0.3984
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 3, 'stack': 2, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.0, 'lr': 0.001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 56 epochs.
# Best model restored from epoch 41 with val_f1 0.4276
#  → F1 Score: 0.4276
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 3, 'stack': 2, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.0, 'lr': 0.0005}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 54 epochs.
# Best model restored from epoch 39 with val_f1 0.4688
#  → F1 Score: 0.4688
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 3, 'stack': 2, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.0, 'lr': 0.0001}
# ========================================
# Training 100 epochs...
# Best model restored from epoch 94 with val_f1 0.4400
#  → F1 Score: 0.4400
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 3, 'stack': 2, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.2, 'lr': 0.001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 46 epochs.
# Best model restored from epoch 31 with val_f1 0.4182
#  → F1 Score: 0.4182
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 3, 'stack': 2, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.2, 'lr': 0.0005}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 32 epochs.
# Best model restored from epoch 17 with val_f1 0.4330
#  → F1 Score: 0.4330
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 3, 'stack': 2, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.2, 'lr': 0.0001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 43 epochs.
# Best model restored from epoch 28 with val_f1 0.2563
#  → F1 Score: 0.2563
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 3, 'stack': 2, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.4, 'lr': 0.001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 38 epochs.
# Best model restored from epoch 23 with val_f1 0.4402
#  → F1 Score: 0.4402
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 3, 'stack': 2, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.4, 'lr': 0.0005}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 30 epochs.
# Best model restored from epoch 15 with val_f1 0.5229
#  → F1 Score: 0.5229
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 3, 'stack': 2, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.4, 'lr': 0.0001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 66 epochs.
# Best model restored from epoch 51 with val_f1 0.3549
#  → F1 Score: 0.3549
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 3, 'stack': 2, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.0, 'lr': 0.001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 22 epochs.
# Best model restored from epoch 7 with val_f1 0.4400
#  → F1 Score: 0.4400
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 3, 'stack': 2, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.0, 'lr': 0.0005}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 53 epochs.
# Best model restored from epoch 38 with val_f1 0.4767
#  → F1 Score: 0.4767
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 3, 'stack': 2, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.0, 'lr': 0.0001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 57 epochs.
# Best model restored from epoch 42 with val_f1 0.4177
#  → F1 Score: 0.4177
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 3, 'stack': 2, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.2, 'lr': 0.001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 34 epochs.
# Best model restored from epoch 19 with val_f1 0.4370
#  → F1 Score: 0.4370
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 3, 'stack': 2, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.2, 'lr': 0.0005}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 64 epochs.
# Best model restored from epoch 49 with val_f1 0.4591
#  → F1 Score: 0.4591
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 3, 'stack': 2, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.2, 'lr': 0.0001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 56 epochs.
# Best model restored from epoch 41 with val_f1 0.4267
#  → F1 Score: 0.4267
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 3, 'stack': 2, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.4, 'lr': 0.001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 50 epochs.
# Best model restored from epoch 35 with val_f1 0.4658
#  → F1 Score: 0.4658
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 3, 'stack': 2, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.4, 'lr': 0.0005}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 32 epochs.
# Best model restored from epoch 17 with val_f1 0.4335
#  → F1 Score: 0.4335
#
# ========================================
# Testing configuration: {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 3, 'stack': 2, 'initial_channels': 32, 'channel_multiplier': 2, 'dropout_rate': 0.4, 'lr': 0.0001}
# ========================================
# Training 100 epochs...
# Early stopping triggered after 42 epochs.
# Best model restored from epoch 27 with val_f1 0.3858
#  → F1 Score: 0.3858
#
# ========================
# Best hyperparameters:
# {'use_stride': False, 'stride_value': 2, 'padding_size': 1, 'pool_size': 2, 'num_blocks': 3, 'stack': 2, 'initial_channels': 16, 'channel_multiplier': 2, 'dropout_rate': 0.4, 'lr': 0.0005}
# Best F1: 0.5228509585652442
# ========================

# %% [markdown]
# ## Inference

# %%
inception_model = best_model

# %%
list_preds = []
list_idx = []
with torch.no_grad():  # Disable gradient computation for inference
    for batch_idx, xb in enumerate(test_loader):
        xb = xb.to(device)

        # permute inputs (This line is incorrect as the data is already in the correct format (Batch, Channels, Height, Width))
        # xb = xb.permute(0, 3, 1, 2)

        # Forward pass: get model predictions
        logits = inception_model(xb)
        preds = logits.argmax(dim=1).cpu().numpy()

        # Store batch results
        list_preds.append(preds)

        # Calculate the actual sample indices for this batch
        start_index = batch_idx * EVAL_BATCH_SIZE
        current_batch_size = len(preds) # Use len(preds) to handle the last batch possibly being smaller
        batch_sample_indices = np.arange(start_index, start_index + current_batch_size)
        list_idx.append(batch_sample_indices)

# Combine all batches into single arrays
list_preds = np.concatenate(list_preds)
list_idx = np.concatenate(list_idx)

# Create a DataFrame for the predictions
df_preds = pd.DataFrame({"sample_index": list_idx, "label": list_preds})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3953053456.py in <cell line: 0>()
#       3 with torch.no_grad():  # Disable gradient computation for inference
#       4     for batch_idx, xb in enumerate(test_loader):
# ----> 5         xb = xb.to(device)
#       6
#       7         # permute inputs (This line is incorrect as the data is already in the correct format (Batch, Channels, Height, Width))
#
# AttributeError: 'list' object has no attribute 'to'

# %%
df_preds
# Out:
#      sample_index  label
# 0               0      1
# 1               1      2
# 2               2      2
# 3               3      2
# 4               4      1
# ..            ...    ...
# 472           472      2
# 473           473      1
# 474           474      2
# 475           475      1
# 476           476      1
#
# [477 rows x 2 columns]

# %%
all_preds = []
all_image_ids = []

with torch.no_grad():
    for xb, image_ids in test_loader:
        xb = xb.to(device)

        logits = inception_model(xb)
        preds = logits.argmax(dim=1).cpu().numpy()

        all_preds.extend(preds)
        # Fix: Remove .numpy() as image_ids is already a list/tuple of strings
        all_image_ids.extend(image_ids)

# Aggregate per image
df_tiles = pd.DataFrame({
    "image_id": all_image_ids,
    "pred": all_preds
})

final_preds = {}

for img_id, group in df_tiles.groupby("image_id"):
    final_preds[img_id] = group["pred"].mode()[0]   # majority vote

# Make submission df
df_preds = pd.DataFrame({
    "sample_index": list(final_preds.keys()),
    "label": list(final_preds.values())
}).sort_values("sample_index")

print(df_preds)
# Out:
#      sample_index  label
# 0    img_0000.png      2
# 1    img_0001.png      1
# 2    img_0002.png      2
# 3    img_0003.png      2
# 4    img_0004.png      2
# ..            ...    ...
# 472  img_0472.png      2
# 473  img_0473.png      3
# 474  img_0474.png      2
# 475  img_0475.png      2
# 476  img_0476.png      2
#
# [477 rows x 2 columns]

# %%
# mapping labels
mapping = {0: 'Triple negative',
             1: 'Luminal A',
             2: 'Luminal B',
             3: 'HER2(+)'}

df_preds['label'] = df_preds['label'].map(mapping)
# df_preds["sample_index"] = df_preds["sample_index"].apply(lambda x: f"img_{int(x):04d}.png")

# %%
df_preds.to_csv('predictions.csv', index=False, header=True)
