# %% [markdown]
# # Baseline CNN model

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Set seed for reproducibility
SEED = 42

# Import necessary libraries
import os
from pathlib import Path


# Set environment variables before importing modules
os.environ['PYTHONHASHSEED'] = str(SEED)
os.environ['MPLCONFIGDIR'] = os.getcwd() + '/configs/'

# Suppress warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

# Import necessary modules
import logging
import random
import numpy as np

# Set seeds for random number generators in NumPy and Python
np.random.seed(SEED)
random.seed(SEED)

# Import PyTorch
import torch
torch.manual_seed(SEED)
from torch import nn
from torchsummary import summary
from torch.utils.tensorboard import SummaryWriter
import torchvision
from torchvision import datasets
import torchvision.transforms.v2 as transforms
from torch.utils.data import TensorDataset, DataLoader
import torch.nn.functional as F

# Configurazione di TensorBoard e directory
logs_dir = "tensorboard"
# !pkill -f tensorboard
# %load_ext tensorboard
# !mkdir -p models

if torch.cuda.is_available():
    device = torch.device("cuda")
    torch.cuda.manual_seed_all(SEED)
    torch.backends.cudnn.benchmark = True
else:
    device = torch.device("cpu")

print(f"PyTorch version: {torch.__version__}")
print(f"Device: {device}")

# Import other libraries
import copy
import shutil
from itertools import product
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.model_selection import train_test_split
from PIL import Image
import matplotlib.gridspec as gridspec


# Configure plot display settings
sns.set(font_scale=1.4)
sns.set_style('white')
plt.rc('font', size=14)
# %matplotlib inline
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# PyTorch version: 2.9.0+cu126
# Device: cuda

# %% [markdown]
# ## Load the dataset

# %%
# Load the preprocessed tensors so we can skip the heavy CSV wrangling

dataset_path = Path("/content/drive/MyDrive/data/dataset_tiling_challenge_2.pt")

if not dataset_path.exists():
    raise FileNotFoundError(
        f"dataset.pt not found"
    )

try:
    bundle = torch.load(dataset_path, map_location="cpu", weights_only=False)
except RuntimeError as err:
        raise


X_train = torch.from_numpy(bundle["X_train"]).permute(0, 3, 1, 2).float()
y_train = torch.from_numpy(bundle["y_train"]).view(-1).long()
X_val = torch.from_numpy(bundle["X_val"]).permute(0, 3, 1, 2).float()
y_val = torch.from_numpy(bundle["y_val"]).view(-1).long()
X_test = torch.from_numpy(bundle["X_test"]).permute(0, 3, 1, 2).float()

if "images_test_name" in bundle:
    images_test_name = bundle["images_test_name"]
else:
    images_test_name = None


print(f"Train tensor shape: {tuple(X_train.shape)}")
print(f"Validation tensor shape: {tuple(X_val.shape)}")
print(f"Test tensor shape: {tuple(X_test.shape)}")
# Out:
# Train tensor shape: (5562, 3, 128, 128)
# Validation tensor shape: (619, 3, 128, 128)
# Test tensor shape: (4414, 3, 128, 128)

# %%
class AugmentedDataset(torch.utils.data.Dataset):
    """
    Custom PyTorch Dataset that applies data augmentation transforms using transforms v2.

    Following the recommended approach from torchvision documentation:
    - Use ToImage() to convert PIL to tensor
    - Use ToDtype(torch.float32, scale=True) to convert to float and scale to [0, 1]

    Args:
        data (np.ndarray): Input images with shape (N, H, W, C)
        labels (np.ndarray): Labels with shape (N,)
        transform (callable, optional): Transform to apply to images
    """
    def __init__(self, data, labels, images_id=None, transform=None):
        self.data = data
        self.labels = labels
        self.images_id = images_id
        self.transform = transform

        # Base transform: convert to tensor (following v2 guidelines)
        self.to_tensor = transforms.Compose([
            transforms.ToImage(), # This will handle (H,W,C) to (C,H,W) if needed, but data is already (C,H,W)
            transforms.ToDtype(torch.float32, scale=True)
        ])

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        # Get image and label
        image = self.data[idx] # This is already a torch.Tensor (float32, 0-1, CHW) due to previous data loading fix

        # Apply base transform: already (CHW), ToImage will pass through, ToDtype ensures float32
        image_tensor = self.to_tensor(image)

        # Apply additional transforms if provided
        if self.transform:
            image_tensor = self.transform(image_tensor)

        if self.images_id is not None:
            return image_tensor , self.images_id[idx]
        if self.labels is None:
            return image_tensor
        label = self.labels[idx]

        return image_tensor, torch.tensor(label, dtype=torch.long)


train_augmentation = transforms.Compose([
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomVerticalFlip(p=0.2),
    transforms.RandomRotation(15),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
    transforms.RandomErasing(p=0.5, scale=(0.02, 0.2), ratio=(0.3, 3.3), value=0),
])

train_ds = AugmentedDataset(X_train, y_train, transform=train_augmentation)
val_ds   = AugmentedDataset(X_val, y_val, transform=None)
test_ds  = AugmentedDataset(X_test, labels=None, images_id=images_test_name, transform=None)

# %%
BATCH_SIZE = 64
EVAL_BATCH_SIZE = 128


def make_loader(dataset, batch_size, shuffle, drop_last):
    """Wrap tensors in a DataLoader."""
    # Setting num_workers to 0 disables multiprocessing for data loading
    # and often resolves issues with FileNotFoundError in _pin_memory_loop
    # Set pin_memory to False as it's often problematic with num_workers > 0 in Colab
    # If performance is an issue, consider experimenting with num_workers = 1 and pin_memory=True
    num_workers = 0 # os.cpu_count() or 2
    return DataLoader(
        dataset,
        batch_size=batch_size,
        shuffle=shuffle,
        drop_last=drop_last,
        num_workers=num_workers,
        pin_memory=False, # Changed to False
        pin_memory_device="cuda" if torch.cuda.is_available() else "",
        prefetch_factor=None, # Changed to None as num_workers is 0
    )

train_loader = make_loader(train_ds, BATCH_SIZE, shuffle=True, drop_last=False)
val_loader = make_loader(val_ds, EVAL_BATCH_SIZE, shuffle=False, drop_last=False)
test_loader = make_loader(test_ds, EVAL_BATCH_SIZE, shuffle=False, drop_last=False)


# Handy metadata for configuring the model
input_size = X_train.shape[1:]
num_classes = len(torch.unique(y_train))
print(f"Input size: {input_size}, classes: {num_classes}")
# Out:
# Input size: torch.Size([3, 128, 128]), classes: 4

# %%
# Fetch a batch to capture the per-sample input shape for summaries
for xb, yb in train_loader:
    input_shape = xb.shape[1:]
    num_classes = len(np.unique(yb.cpu().numpy()))
    break

print(f"Input shape per sample: {input_shape}")
# Out:
# Input shape per sample: torch.Size([3, 128, 128])

# %% [markdown]
# ## CNN class

# %%
class ResidualBlock(nn.Module):
    """Standard Residual Block with stackable units + Final Pooling.
    """
    def __init__(self, in_channels, filters, kernel_size=3, stack=2):
        """Initialises the ResidualBlock.

        Args:
            in_channels (int): Number of input channels.
            filters (int): Number of output filters.
            kernel_size (int, optional): Size of the convolutional kernel. Defaults to 3.
            stack (int, optional): Number of residual units to stack. Defaults to 2.
        """
        super().__init__()

        self.units = nn.ModuleList()
        current_in = in_channels

        for s in range(stack):
            layers = nn.ModuleDict()

            # Standard ResNet Unit: Conv -> BN -> ReLU -> Conv -> BN -> Add -> ReLU
            layers['conv1'] = nn.Conv2d(current_in, filters, kernel_size, padding='same', bias=False)
            layers['bn1'] = nn.BatchNorm2d(filters)
            layers['conv2'] = nn.Conv2d(filters, filters, kernel_size, padding='same', bias=False)
            layers['bn2'] = nn.BatchNorm2d(filters)

            # Skip connection projection if dimensions mismatch
            if current_in != filters:
                layers['proj'] = nn.Sequential(
                    nn.Conv2d(current_in, filters, 1, padding='same', bias=False),
                    nn.BatchNorm2d(filters)
                )

            self.units.append(layers)
            current_in = filters # After first stack, input matches filters

        self.pool = nn.MaxPool2d(2)

    def forward(self, x):
        """Defines the forward pass.

        Args:
            x (torch.Tensor): Input tensor.

        Returns:
            torch.Tensor: Output tensor after block processing.
        """
        for unit in self.units:
            residual = x

            out = unit['conv1'](x)
            out = unit['bn1'](out)
            out = F.relu(out)

            out = unit['conv2'](out)
            out = unit['bn2'](out)

            if 'proj' in unit:
                residual = unit['proj'](residual)

            out += residual
            x = F.relu(out)

        return self.pool(x)

class ResNetModel(nn.Module):
    """Complete CNN model using multiple ResidualBlocks and Global Average Pooling.

    Suitable for classification tasks with deep architectures.
    """
    def __init__(self, input_shape, output_shape, filters=32, kernel_size=3, stack=2, blocks=3):
        """Initialises the ResNetModel.

        Args:
            input_shape (tuple): Shape of the input images (C, H, W).
            output_shape (int): Number of output classes.
            filters (int, optional): Initial number of filters for the first block. Defaults to 32.
            kernel_size (int, optional): Kernel size for convolutional layers. Defaults to 3.
            stack (int, optional): Number of residual units per block. Defaults to 2.
            blocks (int, optional): Number of `ResidualBlock` instances to stack. Defaults to 3.
        """
        super().__init__()

        self.blocks_list = nn.ModuleList()
        current_channels = input_shape[0]
        current_filters = filters

        # Stack ResidualBlocks, typically doubling filters for each.
        for b in range(blocks):
            self.blocks_list.append(
                ResidualBlock(current_channels, current_filters, kernel_size, stack)
            )
            current_channels = current_filters
            current_filters *= 2

        # Global Average Pooling, Flatten, Dropout and Dense layer for classification.
        self.gap = nn.AdaptiveAvgPool2d(1)
        self.flatten = nn.Flatten()
        self.dropout = nn.Dropout(0.5) # Added dropout layer
        self.dense = nn.Linear(current_channels, output_shape)

    def forward(self, x):
        """Defines the forward pass.

        Args:
            x (torch.Tensor): Input tensor.

        Returns:
            torch.Tensor: Output probabilities after Softmax activation.
        """
        for block in self.blocks_list:
            x = block(x)
        x = self.gap(x)
        x = self.flatten(x)
        x = self.dropout(x) # Apply dropout
        x = self.dense(x)
        return F.softmax(x, dim=1)

# %% [markdown]
# ## training and evaluating functions

# %%
def train_one_epoch(model, train_loader, criterion, optimizer, scaler, device, l1_lambda=0, l2_lambda=0):
    """
    Perform one complete training epoch through the entire training dataset.

    Args:
        model (nn.Module): The neural network model to train
        train_loader (DataLoader): PyTorch DataLoader containing training data batches
        criterion (nn.Module): Loss function (e.g., CrossEntropyLoss, MSELoss)
        optimizer (torch.optim): Optimization algorithm (e.g., Adam, SGD)
        scaler (GradScaler): PyTorch's gradient scaler for mixed precision training
        device (torch.device): Computing device ('cuda' for GPU, 'cpu' for CPU)
        l1_lambda (float): Lambda for L1 regularization
        l2_lambda (float): Lambda for L2 regularization

    Returns:
        tuple: (average_loss, f1 score) - Training loss and f1 score for this epoch
    """
    model.train()  # Set model to training mode

    running_loss = 0.0
    all_predictions = []
    all_targets = []

    # Iterate through training batches
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        # Move data to device (GPU/CPU)
        inputs, targets = inputs.to(device), targets.to(device)

        # permute inputs (batch, channel, height, width)
        # inputs = inputs.permute(0, 3, 1, 2) # This line is now redundant after AugmentedDataset fix

        # Clear gradients from previous step
        optimizer.zero_grad(set_to_none=True)

        # Forward pass with mixed precision (if CUDA available)
        with torch.amp.autocast(device_type=device.type, enabled=(device.type == 'cuda')):
            logits = model(inputs)
            loss = criterion(logits, targets)

            # Add L1 and L2 regularization
            l1_norm = sum(p.abs().sum() for p in model.parameters())
            l2_norm = sum(p.pow(2).sum() for p in model.parameters())
            loss = loss + l1_lambda * l1_norm + l2_lambda * l2_norm


        # Backward pass with gradient scaling
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        # Accumulate metrics
        running_loss += loss.item() * inputs.size(0)
        predictions = logits.argmax(dim=1)
        all_predictions.append(predictions.cpu().numpy())
        all_targets.append(targets.cpu().numpy())

    # Calculate epoch metrics
    epoch_loss = running_loss / len(train_loader.dataset)
    epoch_f1 = f1_score(
        np.concatenate(all_targets),
        np.concatenate(all_predictions),
        average='weighted'
    )

    return epoch_loss, epoch_f1

# %%
def validate_one_epoch(model, val_loader, criterion, device):
    """
    Perform one complete validation epoch through the entire validation dataset.

    Args:
        model (nn.Module): The neural network model to evaluate (must be in eval mode)
        val_loader (DataLoader): PyTorch DataLoader containing validation data batches
        criterion (nn.Module): Loss function used to calculate validation loss
        device (torch.device): Computing device ('cuda' for GPU, 'cpu' for CPU)

    Returns:
        tuple: (average_loss, accuracy) - Validation loss and accuracy for this epoch

    Note:
        This function automatically sets the model to evaluation mode and disables
        gradient computation for efficiency during validation.
    """
    model.eval()  # Set model to evaluation mode

    running_loss = 0.0
    all_predictions = []
    all_targets = []

    # Disable gradient computation for validation
    with torch.no_grad():
        for inputs, targets in val_loader:
            # Move data to device
            inputs, targets = inputs.to(device), targets.to(device)

            # permute inputs (batch, channel, height, width)
            # inputs = inputs.permute(0, 3, 1, 2) # This line is now redundant after AugmentedDataset fix

            # Forward pass with mixed precision (if CUDA available)
            with torch.amp.autocast(device_type=device.type, enabled=(device.type == 'cuda')):
                logits = model(inputs)
                loss = criterion(logits, targets)

            # Accumulate metrics
            running_loss += loss.item() * inputs.size(0)
            predictions = logits.argmax(dim=1)
            all_predictions.append(predictions.cpu().numpy())
            all_targets.append(targets.cpu().numpy())

    # Calculate epoch metrics
    epoch_loss = running_loss / len(val_loader.dataset)
    epoch_accuracy = f1_score(
        np.concatenate(all_targets),
        np.concatenate(all_predictions),
        average='weighted'
    )

    return epoch_loss, epoch_accuracy

# %%
def fit(model, train_loader, val_loader, epochs, criterion, optimizer, scaler, scheduler, device,
        l1_lambda=0, l2_lambda=0, patience=0, evaluation_metric="val_f1", mode='max',
        restore_best_weights=True, writer=None, verbose=10, experiment_name=""):
    """
    Train the neural network model on the training data and validate on the validation data.

    Args:
        model (nn.Module): The neural network model to train
        train_loader (DataLoader): PyTorch DataLoader containing training data batches
        val_loader (DataLoader): PyTorch DataLoader containing validation data batches
        epochs (int): Number of training epochs
        criterion (nn.Module): Loss function (e.g., CrossEntropyLoss, MSELoss)
        optimizer (torch.optim): Optimization algorithm (e.g., Adam, SGD)
        scaler (GradScaler): PyTorch's gradient scaler for mixed precision training
        device (torch.device): Computing device ('cuda' for GPU, 'cpu' for CPU)
        l1_lambda (float): L1 regularization coefficient (default: 0)
        l2_lambda (float): L2 regularization coefficient (default: 0)
        patience (int): Number of epochs to wait for improvement before early stopping (default: 0)
        evaluation_metric (str): Metric to monitor for early stopping (default: "val_f1")
        mode (str): 'max' for maximizing the metric, 'min' for minimizing (default: 'max')
        restore_best_weights (bool): Whether to restore model weights from best epoch (default: True)
        writer (SummaryWriter, optional): TensorBoard SummaryWriter object for logging (default: None)
        verbose (int, optional): Frequency of printing training progress (default: 10)
        experiment_name (str, optional): Experiment name for saving models (default: "")

    Returns:
        tuple: (model, training_history) - Trained model and metrics history
    """

    # Initialize metrics tracking
    training_history = {
        'train_loss': [], 'val_loss': [],
        'train_f1': [], 'val_f1': []
    }

    # Configure early stopping if patience is set
    if patience > 0:
        patience_counter = 0
        best_metric = float('-inf') if mode == 'max' else float('inf')
        best_epoch = 0

    print(f"Training {epochs} epochs...")

    # Main training loop: iterate through epochs
    for epoch in range(1, epochs + 1):

        # Forward pass through training data, compute gradients, update weights
        train_loss, train_f1 = train_one_epoch(
            model, train_loader, criterion, optimizer, scaler, device, l1_lambda, l2_lambda
        )

        # Evaluate model on validation data without updating weights
        val_loss, val_f1 = validate_one_epoch(
            model, val_loader, criterion, device
        )

        scheduler.step()

        # Store metrics for plotting and analysis
        training_history['train_loss'].append(train_loss)
        training_history['val_loss'].append(val_loss)
        training_history['train_f1'].append(train_f1)
        training_history['val_f1'].append(val_f1)


        # Print progress every N epochs or on first epoch
        if verbose > 0:
            if epoch % verbose == 0 or epoch == 1:
                print(f"Epoch {epoch:3d}/{epochs} | "
                    f"Train: Loss={train_loss:.4f}, F1 Score={train_f1:.4f} | "
                    f"Val: Loss={val_loss:.4f}, F1 Score={val_f1:.4f}")

        # Early stopping logic: monitor metric and save best model
        if patience > 0:
            current_metric = training_history[evaluation_metric][-1]
            is_improvement = (current_metric > best_metric) if mode == 'max' else (current_metric < best_metric)

            if is_improvement:
                best_metric = current_metric
                best_epoch = epoch
                torch.save(model.state_dict(), "models/"+experiment_name+'_model.pt')
                patience_counter = 0
            else:
                patience_counter += 1
                if patience_counter >= patience:
                    print(f"Early stopping triggered after {epoch} epochs.")
                    break

    # Restore best model weights if early stopping was used
    if restore_best_weights and patience > 0:
        model.load_state_dict(torch.load("models/"+experiment_name+'_model.pt'))
        print(f"Best model restored from epoch {best_epoch} with {evaluation_metric} {best_metric:.4f}")

    # Save final model if no early stopping
    if patience == 0:
        torch.save(model.state_dict(), "models/"+experiment_name+'_model.pt')

    # Close TensorBoard writer
    if writer is not None:
        writer.close()

    return model, training_history

# %% [markdown]
# ## Hyperparameters

# %%
# Number of training epochs
LEARNING_RATE = 3e-4
EPOCHS = 300
PATIENCE = 75

# Regularisation
L1_LAMBDA = 1e-6            # L1 penalty
L2_LAMBDA = 3e-4            # L2 penalty

# CNN Architecture parameters for grid search (will need model definition update)
KERNEL_SIZE = 3

# Set up loss function and optimizer
criterion = nn.CrossEntropyLoss(label_smoothing=0.1)

# Print the defined parameters
print("Epochs:", EPOCHS)
print("Batch Size:", BATCH_SIZE)
print("Learning Rare:", LEARNING_RATE)
print("L1 Penalty:", L1_LAMBDA)
print("L2 Penalty:", L2_LAMBDA)
print("Kernel Size:", KERNEL_SIZE)
# Out:
# Epochs: 300
# Batch Size: 64
# Learning Rare: 0.0003
# L1 Penalty: 1e-06
# L2 Penalty: 0.0003
# Kernel Size: 3

# %%
# CNN Architecture parameters
# Number of convolutional blocks
NUM_BLOCKS = 1

FILTERS = 32

STACK = 2 # Changed STACK from 1 to 2

BLOCKS = 3

print("Num Blocks:", NUM_BLOCKS)
print("Channel Multiplier:", FILTERS)
print("Channel Multiplier:", STACK)
print("Channel Multiplier:", BLOCKS)
# Out:
# Num Blocks: 1
# Channel Multiplier: 32
# Channel Multiplier: 2
# Channel Multiplier: 3

# %% [markdown]
# ## Training

# %%
# Initialize best model tracking variables
best_model = None
best_performance = float('-inf')

# %%
# Instantiate CNN model and move to computing device (CPU/GPU)


cnn_model = ResNetModel(
    input_shape,
    num_classes,
    filters=FILTERS,
    kernel_size=KERNEL_SIZE,
    stack=STACK,
    blocks=BLOCKS
    ).to(device)

# Display model architecture summary
summary(cnn_model, input_size=input_shape)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 32, 128, 128]             864
#        BatchNorm2d-2         [-1, 32, 128, 128]              64
#             Conv2d-3         [-1, 32, 128, 128]           9,216
#        BatchNorm2d-4         [-1, 32, 128, 128]              64
#             Conv2d-5         [-1, 32, 128, 128]              96
#        BatchNorm2d-6         [-1, 32, 128, 128]              64
#             Conv2d-7         [-1, 32, 128, 128]           9,216
#        BatchNorm2d-8         [-1, 32, 128, 128]              64
#             Conv2d-9         [-1, 32, 128, 128]           9,216
#       BatchNorm2d-10         [-1, 32, 128, 128]              64
#         MaxPool2d-11           [-1, 32, 64, 64]               0
#     ResidualBlock-12           [-1, 32, 64, 64]               0
#            Conv2d-13           [-1, 64, 64, 64]          18,432
#       BatchNorm2d-14           [-1, 64, 64, 64]             128
#            Conv2d-15           [-1, 64, 64, 64]          36,864
#       BatchNorm2d-16           [-1, 64, 64, 64]             128
#            Conv2d-17           [-1, 64, 64, 64]           2,048
#       BatchNorm2d-18           [-1, 64, 64, 64]             128
#            Conv2d-19           [-1, 64, 64, 64]          36,864
#       BatchNorm2d-20           [-1, 64, 64, 64]             128
#            Conv2d-21           [-1, 64, 64, 64]          36,864
#       BatchNorm2d-22           [-1, 64, 64, 64]             128
#         MaxPool2d-23           [-1, 64, 32, 32]               0
#     ResidualBlock-24           [-1, 64, 32, 32]               0
#            Conv2d-25          [-1, 128, 32, 32]          73,728
#       BatchNorm2d-26          [-1, 128, 32, 32]             256
#            Conv2d-27          [-1, 128, 32, 32]         147,456
#       BatchNorm2d-28          [-1, 128, 32, 32]             256
#            Conv2d-29          [-1, 128, 32, 32]           8,192
#       BatchNorm2d-30          [-1, 128, 32, 32]             256
#            Conv2d-31          [-1, 128, 32, 32]         147,456
#       BatchNorm2d-32          [-1, 128, 32, 32]             256
#            Conv2d-33          [-1, 128, 32, 32]         147,456
#       BatchNorm2d-34          [-1, 128, 32, 32]             256
#         MaxPool2d-35          [-1, 128, 16, 16]               0
#     ResidualBlock-36          [-1, 128, 16, 16]               0
# AdaptiveAvgPool2d-37            [-1, 128, 1, 1]               0
#           Flatten-38                  [-1, 128]               0
#           Dropout-39                  [-1, 128]               0
#            Linear-40                    [-1, 4]             516
# ================================================================
# Total params: 686,724
# Trainable params: 686,724
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.19
# Forward/backward pass size (MB): 73.50
# Params size (MB): 2.62
# Estimated Total Size (MB): 76.31
# ----------------------------------------------------------------

# %%
# Define optimizer with L2 regularization
optimizer = torch.optim.AdamW(cnn_model.parameters(), lr=LEARNING_RATE, weight_decay=L2_LAMBDA)

# Enable mixed precision training for GPU acceleration
scaler = torch.amp.GradScaler(enabled=(device.type == 'cuda'))

scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
    optimizer,
    T_max=EPOCHS,       # your total epochs
    eta_min=1e-6
)

# %%
experiment_name = "cnn_RES_3"

writer = SummaryWriter(f"./{logs_dir}/cnn")


# %%time
# Train model and track training history
cnn_model, training_history = fit(
    model=cnn_model,
    train_loader=train_loader,
    val_loader=val_loader,
    epochs=EPOCHS,
    criterion=criterion,
    optimizer=optimizer,
    scaler=scaler,
    scheduler=scheduler,
    device=device,
    l1_lambda=L1_LAMBDA,
    l2_lambda=L2_LAMBDA,
    patience=PATIENCE,
    evaluation_metric="val_f1",
    mode='max',
    restore_best_weights=True,
    writer=writer,
    verbose=1,
    experiment_name=experiment_name,
    )

# Update best model if current performance is superior
if training_history['val_f1'][-1] > best_performance:
    best_model = cnn_model
    best_performance = training_history['val_f1'][-1]
# Out:
# Training 200 epochs...
# Epoch   1/200 | Train: Loss=1.7858, F1 Score=0.3504 | Val: Loss=1.3125, F1 Score=0.3472
# Epoch   2/200 | Train: Loss=1.7585, F1 Score=0.3571 | Val: Loss=1.3077, F1 Score=0.3329
# Epoch   3/200 | Train: Loss=1.7347, F1 Score=0.3581 | Val: Loss=1.3110, F1 Score=0.3573
# Epoch   4/200 | Train: Loss=1.7135, F1 Score=0.3625 | Val: Loss=1.3067, F1 Score=0.3491
# Epoch   5/200 | Train: Loss=1.6900, F1 Score=0.3674 | Val: Loss=1.3062, F1 Score=0.3462
# Epoch   6/200 | Train: Loss=1.6696, F1 Score=0.3629 | Val: Loss=1.3030, F1 Score=0.3667
# Epoch   7/200 | Train: Loss=1.6534, F1 Score=0.3636 | Val: Loss=1.3054, F1 Score=0.3498
# Epoch   8/200 | Train: Loss=1.6295, F1 Score=0.3687 | Val: Loss=1.3018, F1 Score=0.3743
# Epoch   9/200 | Train: Loss=1.6152, F1 Score=0.3716 | Val: Loss=1.2995, F1 Score=0.3450
# Epoch  10/200 | Train: Loss=1.5985, F1 Score=0.3700 | Val: Loss=1.2965, F1 Score=0.3737
# Epoch  11/200 | Train: Loss=1.5853, F1 Score=0.3668 | Val: Loss=1.2945, F1 Score=0.3690
# Epoch  12/200 | Train: Loss=1.5675, F1 Score=0.3811 | Val: Loss=1.2995, F1 Score=0.3489
# Epoch  13/200 | Train: Loss=1.5534, F1 Score=0.3782 | Val: Loss=1.2998, F1 Score=0.3483
# Epoch  14/200 | Train: Loss=1.5428, F1 Score=0.3857 | Val: Loss=1.3095, F1 Score=0.3311
# Epoch  15/200 | Train: Loss=1.5320, F1 Score=0.3818 | Val: Loss=1.3066, F1 Score=0.3249
# Epoch  16/200 | Train: Loss=1.5216, F1 Score=0.3759 | Val: Loss=1.3007, F1 Score=0.3483
# Epoch  17/200 | Train: Loss=1.5089, F1 Score=0.3800 | Val: Loss=1.2911, F1 Score=0.3790
# Epoch  18/200 | Train: Loss=1.4983, F1 Score=0.3826 | Val: Loss=1.3012, F1 Score=0.3839
# Epoch  19/200 | Train: Loss=1.4928, F1 Score=0.3822 | Val: Loss=1.2944, F1 Score=0.3455
# Epoch  20/200 | Train: Loss=1.4808, F1 Score=0.3886 | Val: Loss=1.2992, F1 Score=0.3476
# Epoch  21/200 | Train: Loss=1.4718, F1 Score=0.3927 | Val: Loss=1.3074, F1 Score=0.3518
# Epoch  22/200 | Train: Loss=1.4631, F1 Score=0.3874 | Val: Loss=1.2933, F1 Score=0.3628
# Epoch  23/200 | Train: Loss=1.4570, F1 Score=0.3919 | Val: Loss=1.2964, F1 Score=0.3888
# Epoch  24/200 | Train: Loss=1.4514, F1 Score=0.3893 | Val: Loss=1.2952, F1 Score=0.3878
# Epoch  25/200 | Train: Loss=1.4434, F1 Score=0.3952 | Val: Loss=1.3153, F1 Score=0.3507
# Epoch  26/200 | Train: Loss=1.4376, F1 Score=0.3960 | Val: Loss=1.3027, F1 Score=0.3448
# Epoch  27/200 | Train: Loss=1.4300, F1 Score=0.3928 | Val: Loss=1.2886, F1 Score=0.3877
# Epoch  28/200 | Train: Loss=1.4273, F1 Score=0.3921 | Val: Loss=1.3031, F1 Score=0.3637
# Epoch  29/200 | Train: Loss=1.4206, F1 Score=0.3914 | Val: Loss=1.2979, F1 Score=0.3755
# Epoch  30/200 | Train: Loss=1.4152, F1 Score=0.3906 | Val: Loss=1.2930, F1 Score=0.3793
# Epoch  31/200 | Train: Loss=1.4066, F1 Score=0.4059 | Val: Loss=1.2923, F1 Score=0.3915
# Epoch  32/200 | Train: Loss=1.4078, F1 Score=0.3942 | Val: Loss=1.3058, F1 Score=0.3572
# Epoch  33/200 | Train: Loss=1.3985, F1 Score=0.4058 | Val: Loss=1.2985, F1 Score=0.3693
# Epoch  34/200 | Train: Loss=1.3990, F1 Score=0.3944 | Val: Loss=1.2946, F1 Score=0.3906
# Epoch  35/200 | Train: Loss=1.3970, F1 Score=0.4023 | Val: Loss=1.2970, F1 Score=0.3678
# Epoch  36/200 | Train: Loss=1.3891, F1 Score=0.4025 | Val: Loss=1.2950, F1 Score=0.3913
# Epoch  37/200 | Train: Loss=1.3846, F1 Score=0.4125 | Val: Loss=1.2850, F1 Score=0.4158
# Epoch  38/200 | Train: Loss=1.3815, F1 Score=0.4029 | Val: Loss=1.2981, F1 Score=0.3576
# Epoch  39/200 | Train: Loss=1.3787, F1 Score=0.3998 | Val: Loss=1.2880, F1 Score=0.3874
# Epoch  40/200 | Train: Loss=1.3757, F1 Score=0.4131 | Val: Loss=1.2914, F1 Score=0.3759
# Epoch  41/200 | Train: Loss=1.3728, F1 Score=0.4104 | Val: Loss=1.2938, F1 Score=0.3715
# Epoch  42/200 | Train: Loss=1.3691, F1 Score=0.4136 | Val: Loss=1.2953, F1 Score=0.3658
# Epoch  43/200 | Train: Loss=1.3692, F1 Score=0.4025 | Val: Loss=1.2979, F1 Score=0.3775
# Epoch  44/200 | Train: Loss=1.3674, F1 Score=0.4124 | Val: Loss=1.2929, F1 Score=0.3799
# Epoch  45/200 | Train: Loss=1.3625, F1 Score=0.4207 | Val: Loss=1.2877, F1 Score=0.4094
# Epoch  46/200 | Train: Loss=1.3635, F1 Score=0.4059 | Val: Loss=1.2936, F1 Score=0.3954
# Epoch  47/200 | Train: Loss=1.3635, F1 Score=0.4079 | Val: Loss=1.2878, F1 Score=0.3927
# Epoch  48/200 | Train: Loss=1.3569, F1 Score=0.4158 | Val: Loss=1.2871, F1 Score=0.3968
# Epoch  49/200 | Train: Loss=1.3566, F1 Score=0.4132 | Val: Loss=1.2952, F1 Score=0.3948
# Epoch  50/200 | Train: Loss=1.3516, F1 Score=0.4200 | Val: Loss=1.3127, F1 Score=0.3674
# Epoch  51/200 | Train: Loss=1.3494, F1 Score=0.4218 | Val: Loss=1.2876, F1 Score=0.3960
# Epoch  52/200 | Train: Loss=1.3508, F1 Score=0.4242 | Val: Loss=1.2890, F1 Score=0.3822
# Epoch  53/200 | Train: Loss=1.3511, F1 Score=0.4134 | Val: Loss=1.3012, F1 Score=0.3744
# Epoch  54/200 | Train: Loss=1.3463, F1 Score=0.4182 | Val: Loss=1.3040, F1 Score=0.3626
# Epoch  55/200 | Train: Loss=1.3451, F1 Score=0.4218 | Val: Loss=1.3171, F1 Score=0.3684
# Epoch  56/200 | Train: Loss=1.3430, F1 Score=0.4270 | Val: Loss=1.2785, F1 Score=0.4351
# Epoch  57/200 | Train: Loss=1.3399, F1 Score=0.4284 | Val: Loss=1.3303, F1 Score=0.3349
# Epoch  58/200 | Train: Loss=1.3392, F1 Score=0.4300 | Val: Loss=1.2971, F1 Score=0.3679
# Epoch  59/200 | Train: Loss=1.3410, F1 Score=0.4210 | Val: Loss=1.2960, F1 Score=0.4273
# Epoch  60/200 | Train: Loss=1.3400, F1 Score=0.4245 | Val: Loss=1.2983, F1 Score=0.3909
# Epoch  61/200 | Train: Loss=1.3355, F1 Score=0.4262 | Val: Loss=1.2923, F1 Score=0.3613
# Epoch  62/200 | Train: Loss=1.3376, F1 Score=0.4285 | Val: Loss=1.2762, F1 Score=0.4378
# Epoch  63/200 | Train: Loss=1.3324, F1 Score=0.4431 | Val: Loss=1.3073, F1 Score=0.3771
# Epoch  64/200 | Train: Loss=1.3339, F1 Score=0.4360 | Val: Loss=1.3093, F1 Score=0.3526
# Epoch  65/200 | Train: Loss=1.3298, F1 Score=0.4381 | Val: Loss=1.2728, F1 Score=0.4303
# Epoch  66/200 | Train: Loss=1.3323, F1 Score=0.4312 | Val: Loss=1.2902, F1 Score=0.3840
# Epoch  67/200 | Train: Loss=1.3296, F1 Score=0.4405 | Val: Loss=1.2886, F1 Score=0.4039
# Epoch  68/200 | Train: Loss=1.3273, F1 Score=0.4359 | Val: Loss=1.2808, F1 Score=0.4092
# Epoch  69/200 | Train: Loss=1.3240, F1 Score=0.4437 | Val: Loss=1.2838, F1 Score=0.4115
# Epoch  70/200 | Train: Loss=1.3285, F1 Score=0.4382 | Val: Loss=1.2737, F1 Score=0.4299
# Epoch  71/200 | Train: Loss=1.3248, F1 Score=0.4393 | Val: Loss=1.2880, F1 Score=0.3952
# Epoch  72/200 | Train: Loss=1.3221, F1 Score=0.4426 | Val: Loss=1.2790, F1 Score=0.4216
# Epoch  73/200 | Train: Loss=1.3238, F1 Score=0.4461 | Val: Loss=1.2822, F1 Score=0.4318
# Epoch  74/200 | Train: Loss=1.3214, F1 Score=0.4450 | Val: Loss=1.2861, F1 Score=0.3927
# Epoch  75/200 | Train: Loss=1.3224, F1 Score=0.4503 | Val: Loss=1.2731, F1 Score=0.4434
# Epoch  76/200 | Train: Loss=1.3205, F1 Score=0.4521 | Val: Loss=1.2786, F1 Score=0.4068
# Epoch  77/200 | Train: Loss=1.3169, F1 Score=0.4588 | Val: Loss=1.2813, F1 Score=0.4163
# Epoch  78/200 | Train: Loss=1.3172, F1 Score=0.4566 | Val: Loss=1.2799, F1 Score=0.4156
# Epoch  79/200 | Train: Loss=1.3155, F1 Score=0.4664 | Val: Loss=1.2720, F1 Score=0.4303
# Epoch  80/200 | Train: Loss=1.3126, F1 Score=0.4597 | Val: Loss=1.3136, F1 Score=0.3779
# Epoch  81/200 | Train: Loss=1.3141, F1 Score=0.4638 | Val: Loss=1.2828, F1 Score=0.4071
# Epoch  82/200 | Train: Loss=1.3147, F1 Score=0.4550 | Val: Loss=1.2792, F1 Score=0.4099
# Epoch  83/200 | Train: Loss=1.3096, F1 Score=0.4678 | Val: Loss=1.3000, F1 Score=0.3873
# Epoch  84/200 | Train: Loss=1.3143, F1 Score=0.4613 | Val: Loss=1.2702, F1 Score=0.4634
# Epoch  85/200 | Train: Loss=1.3096, F1 Score=0.4682 | Val: Loss=1.2785, F1 Score=0.4183
# Epoch  86/200 | Train: Loss=1.3109, F1 Score=0.4585 | Val: Loss=1.2817, F1 Score=0.4066
# Epoch  87/200 | Train: Loss=1.3120, F1 Score=0.4644 | Val: Loss=1.2801, F1 Score=0.4145
# Epoch  88/200 | Train: Loss=1.3043, F1 Score=0.4733 | Val: Loss=1.3133, F1 Score=0.3615
# Epoch  89/200 | Train: Loss=1.3067, F1 Score=0.4679 | Val: Loss=1.2862, F1 Score=0.4142
# Epoch  90/200 | Train: Loss=1.3060, F1 Score=0.4733 | Val: Loss=1.2743, F1 Score=0.4338
# Epoch  91/200 | Train: Loss=1.3073, F1 Score=0.4673 | Val: Loss=1.2766, F1 Score=0.4326
# Epoch  92/200 | Train: Loss=1.3068, F1 Score=0.4656 | Val: Loss=1.2695, F1 Score=0.4432
# Epoch  93/200 | Train: Loss=1.3059, F1 Score=0.4663 | Val: Loss=1.2927, F1 Score=0.4085
# Epoch  94/200 | Train: Loss=1.3056, F1 Score=0.4647 | Val: Loss=1.2750, F1 Score=0.4240
# Epoch  95/200 | Train: Loss=1.3009, F1 Score=0.4717 | Val: Loss=1.2622, F1 Score=0.4567
# Epoch  96/200 | Train: Loss=1.3027, F1 Score=0.4746 | Val: Loss=1.2809, F1 Score=0.4088
# Epoch  97/200 | Train: Loss=1.3032, F1 Score=0.4720 | Val: Loss=1.2827, F1 Score=0.4190
# Epoch  98/200 | Train: Loss=1.3027, F1 Score=0.4733 | Val: Loss=1.2864, F1 Score=0.4188
# Epoch  99/200 | Train: Loss=1.3022, F1 Score=0.4702 | Val: Loss=1.2946, F1 Score=0.4279
# Epoch 100/200 | Train: Loss=1.3052, F1 Score=0.4744 | Val: Loss=1.2819, F1 Score=0.4289
# Epoch 101/200 | Train: Loss=1.3036, F1 Score=0.4686 | Val: Loss=1.2702, F1 Score=0.4373
# Epoch 102/200 | Train: Loss=1.2993, F1 Score=0.4759 | Val: Loss=1.2953, F1 Score=0.3902
# Epoch 103/200 | Train: Loss=1.2967, F1 Score=0.4767 | Val: Loss=1.2738, F1 Score=0.4492
# Epoch 104/200 | Train: Loss=1.2987, F1 Score=0.4748 | Val: Loss=1.2645, F1 Score=0.4664
# Epoch 105/200 | Train: Loss=1.2976, F1 Score=0.4800 | Val: Loss=1.2602, F1 Score=0.4726
# Epoch 106/200 | Train: Loss=1.2969, F1 Score=0.4795 | Val: Loss=1.2592, F1 Score=0.4781
# Epoch 107/200 | Train: Loss=1.2958, F1 Score=0.4741 | Val: Loss=1.2627, F1 Score=0.4538
# Epoch 108/200 | Train: Loss=1.2936, F1 Score=0.4822 | Val: Loss=1.2750, F1 Score=0.4207
# Epoch 109/200 | Train: Loss=1.2942, F1 Score=0.4835 | Val: Loss=1.2606, F1 Score=0.4665
# Epoch 110/200 | Train: Loss=1.2917, F1 Score=0.4813 | Val: Loss=1.2624, F1 Score=0.4489
# Epoch 111/200 | Train: Loss=1.2951, F1 Score=0.4796 | Val: Loss=1.2740, F1 Score=0.4227
# Epoch 112/200 | Train: Loss=1.2908, F1 Score=0.4833 | Val: Loss=1.2633, F1 Score=0.4514
# Epoch 113/200 | Train: Loss=1.2904, F1 Score=0.4875 | Val: Loss=1.2753, F1 Score=0.4421
# Epoch 114/200 | Train: Loss=1.2898, F1 Score=0.4875 | Val: Loss=1.2671, F1 Score=0.4481
# Epoch 115/200 | Train: Loss=1.2893, F1 Score=0.4897 | Val: Loss=1.2717, F1 Score=0.4321
# Epoch 116/200 | Train: Loss=1.2906, F1 Score=0.4881 | Val: Loss=1.2762, F1 Score=0.4431
# Epoch 117/200 | Train: Loss=1.2908, F1 Score=0.4858 | Val: Loss=1.2677, F1 Score=0.4661
# Epoch 118/200 | Train: Loss=1.2906, F1 Score=0.4847 | Val: Loss=1.2605, F1 Score=0.4609
# Epoch 119/200 | Train: Loss=1.2899, F1 Score=0.4878 | Val: Loss=1.2504, F1 Score=0.4770
# Epoch 120/200 | Train: Loss=1.2881, F1 Score=0.4893 | Val: Loss=1.2686, F1 Score=0.4366
# Epoch 121/200 | Train: Loss=1.2882, F1 Score=0.4822 | Val: Loss=1.2596, F1 Score=0.4509
# Epoch 122/200 | Train: Loss=1.2888, F1 Score=0.4882 | Val: Loss=1.2496, F1 Score=0.4768
# Epoch 123/200 | Train: Loss=1.2864, F1 Score=0.4949 | Val: Loss=1.2467, F1 Score=0.4884
# Epoch 124/200 | Train: Loss=1.2857, F1 Score=0.5010 | Val: Loss=1.2562, F1 Score=0.4753
# Epoch 125/200 | Train: Loss=1.2835, F1 Score=0.4929 | Val: Loss=1.2525, F1 Score=0.4709
# Epoch 126/200 | Train: Loss=1.2841, F1 Score=0.4978 | Val: Loss=1.2556, F1 Score=0.4734
# Epoch 127/200 | Train: Loss=1.2803, F1 Score=0.5013 | Val: Loss=1.2505, F1 Score=0.4928
# Epoch 128/200 | Train: Loss=1.2827, F1 Score=0.5044 | Val: Loss=1.2542, F1 Score=0.4767
# Epoch 129/200 | Train: Loss=1.2846, F1 Score=0.4954 | Val: Loss=1.2626, F1 Score=0.4571
# Epoch 130/200 | Train: Loss=1.2823, F1 Score=0.5007 | Val: Loss=1.2560, F1 Score=0.4717
# Epoch 131/200 | Train: Loss=1.2803, F1 Score=0.5017 | Val: Loss=1.2619, F1 Score=0.4583
# Epoch 132/200 | Train: Loss=1.2837, F1 Score=0.4988 | Val: Loss=1.2477, F1 Score=0.4804
# Epoch 133/200 | Train: Loss=1.2805, F1 Score=0.5020 | Val: Loss=1.2671, F1 Score=0.4458
# Epoch 134/200 | Train: Loss=1.2798, F1 Score=0.5046 | Val: Loss=1.2578, F1 Score=0.4659
# Epoch 135/200 | Train: Loss=1.2824, F1 Score=0.4940 | Val: Loss=1.2529, F1 Score=0.4768
# Epoch 136/200 | Train: Loss=1.2798, F1 Score=0.4986 | Val: Loss=1.2526, F1 Score=0.4869
# Epoch 137/200 | Train: Loss=1.2778, F1 Score=0.4990 | Val: Loss=1.2553, F1 Score=0.4661
# Epoch 138/200 | Train: Loss=1.2759, F1 Score=0.5112 | Val: Loss=1.2539, F1 Score=0.4887
# Epoch 139/200 | Train: Loss=1.2772, F1 Score=0.5039 | Val: Loss=1.2442, F1 Score=0.4848
# Epoch 140/200 | Train: Loss=1.2768, F1 Score=0.5075 | Val: Loss=1.2475, F1 Score=0.4803
# Epoch 141/200 | Train: Loss=1.2798, F1 Score=0.5006 | Val: Loss=1.2504, F1 Score=0.4719
# Epoch 142/200 | Train: Loss=1.2759, F1 Score=0.5041 | Val: Loss=1.2455, F1 Score=0.4856
# Epoch 143/200 | Train: Loss=1.2751, F1 Score=0.5095 | Val: Loss=1.2491, F1 Score=0.4886
# Epoch 144/200 | Train: Loss=1.2762, F1 Score=0.4987 | Val: Loss=1.2454, F1 Score=0.4970
# Epoch 145/200 | Train: Loss=1.2755, F1 Score=0.5101 | Val: Loss=1.2435, F1 Score=0.4809
# Epoch 146/200 | Train: Loss=1.2775, F1 Score=0.5041 | Val: Loss=1.2520, F1 Score=0.4519
# Epoch 147/200 | Train: Loss=1.2797, F1 Score=0.5033 | Val: Loss=1.2433, F1 Score=0.4998
# Epoch 148/200 | Train: Loss=1.2702, F1 Score=0.5172 | Val: Loss=1.2424, F1 Score=0.5007
# Epoch 149/200 | Train: Loss=1.2730, F1 Score=0.5132 | Val: Loss=1.2441, F1 Score=0.4886
# Epoch 150/200 | Train: Loss=1.2705, F1 Score=0.5188 | Val: Loss=1.2468, F1 Score=0.4763
# Epoch 151/200 | Train: Loss=1.2696, F1 Score=0.5148 | Val: Loss=1.2456, F1 Score=0.4790
# Epoch 152/200 | Train: Loss=1.2689, F1 Score=0.5148 | Val: Loss=1.2465, F1 Score=0.4758
# Epoch 153/200 | Train: Loss=1.2687, F1 Score=0.5166 | Val: Loss=1.2432, F1 Score=0.4853
# Epoch 154/200 | Train: Loss=1.2701, F1 Score=0.5155 | Val: Loss=1.2416, F1 Score=0.4944
# Epoch 155/200 | Train: Loss=1.2704, F1 Score=0.5170 | Val: Loss=1.2402, F1 Score=0.4884
# Epoch 156/200 | Train: Loss=1.2690, F1 Score=0.5178 | Val: Loss=1.2363, F1 Score=0.5017
# Epoch 157/200 | Train: Loss=1.2674, F1 Score=0.5206 | Val: Loss=1.2497, F1 Score=0.4744
# Epoch 158/200 | Train: Loss=1.2693, F1 Score=0.5142 | Val: Loss=1.2372, F1 Score=0.4911
# Epoch 159/200 | Train: Loss=1.2686, F1 Score=0.5185 | Val: Loss=1.2401, F1 Score=0.4871
# Epoch 160/200 | Train: Loss=1.2655, F1 Score=0.5215 | Val: Loss=1.2412, F1 Score=0.4779
# Epoch 161/200 | Train: Loss=1.2668, F1 Score=0.5175 | Val: Loss=1.2471, F1 Score=0.4799
# Epoch 162/200 | Train: Loss=1.2674, F1 Score=0.5195 | Val: Loss=1.2422, F1 Score=0.4830
# Epoch 163/200 | Train: Loss=1.2656, F1 Score=0.5170 | Val: Loss=1.2359, F1 Score=0.5051
# Epoch 164/200 | Train: Loss=1.2650, F1 Score=0.5242 | Val: Loss=1.2341, F1 Score=0.5046
# Epoch 165/200 | Train: Loss=1.2639, F1 Score=0.5240 | Val: Loss=1.2375, F1 Score=0.5060
# Epoch 166/200 | Train: Loss=1.2652, F1 Score=0.5243 | Val: Loss=1.2388, F1 Score=0.4961
# Epoch 167/200 | Train: Loss=1.2626, F1 Score=0.5288 | Val: Loss=1.2420, F1 Score=0.4765
# Epoch 168/200 | Train: Loss=1.2653, F1 Score=0.5230 | Val: Loss=1.2368, F1 Score=0.5033
# Epoch 169/200 | Train: Loss=1.2602, F1 Score=0.5311 | Val: Loss=1.2381, F1 Score=0.4904
# Epoch 170/200 | Train: Loss=1.2649, F1 Score=0.5251 | Val: Loss=1.2400, F1 Score=0.4960
# Epoch 171/200 | Train: Loss=1.2598, F1 Score=0.5306 | Val: Loss=1.2352, F1 Score=0.4978
# Epoch 172/200 | Train: Loss=1.2598, F1 Score=0.5294 | Val: Loss=1.2305, F1 Score=0.5079
# Epoch 173/200 | Train: Loss=1.2600, F1 Score=0.5323 | Val: Loss=1.2349, F1 Score=0.4958
# Epoch 174/200 | Train: Loss=1.2600, F1 Score=0.5331 | Val: Loss=1.2323, F1 Score=0.5034
# Epoch 175/200 | Train: Loss=1.2617, F1 Score=0.5275 | Val: Loss=1.2330, F1 Score=0.4930
# Epoch 176/200 | Train: Loss=1.2618, F1 Score=0.5294 | Val: Loss=1.2307, F1 Score=0.5143
# Epoch 177/200 | Train: Loss=1.2625, F1 Score=0.5222 | Val: Loss=1.2324, F1 Score=0.5050
# Epoch 178/200 | Train: Loss=1.2608, F1 Score=0.5260 | Val: Loss=1.2310, F1 Score=0.5051
# Epoch 179/200 | Train: Loss=1.2615, F1 Score=0.5267 | Val: Loss=1.2312, F1 Score=0.5146
# Epoch 180/200 | Train: Loss=1.2615, F1 Score=0.5279 | Val: Loss=1.2337, F1 Score=0.4933
# Epoch 181/200 | Train: Loss=1.2596, F1 Score=0.5320 | Val: Loss=1.2319, F1 Score=0.5084
# Epoch 182/200 | Train: Loss=1.2581, F1 Score=0.5291 | Val: Loss=1.2291, F1 Score=0.5110
# Epoch 183/200 | Train: Loss=1.2596, F1 Score=0.5301 | Val: Loss=1.2302, F1 Score=0.5055
# Epoch 184/200 | Train: Loss=1.2602, F1 Score=0.5354 | Val: Loss=1.2288, F1 Score=0.5228
# Epoch 185/200 | Train: Loss=1.2597, F1 Score=0.5275 | Val: Loss=1.2307, F1 Score=0.5198
# Epoch 186/200 | Train: Loss=1.2596, F1 Score=0.5306 | Val: Loss=1.2302, F1 Score=0.5117
# Epoch 187/200 | Train: Loss=1.2609, F1 Score=0.5282 | Val: Loss=1.2329, F1 Score=0.4971
# Epoch 188/200 | Train: Loss=1.2595, F1 Score=0.5318 | Val: Loss=1.2305, F1 Score=0.5121
# Epoch 189/200 | Train: Loss=1.2595, F1 Score=0.5306 | Val: Loss=1.2317, F1 Score=0.4996
# Epoch 190/200 | Train: Loss=1.2557, F1 Score=0.5358 | Val: Loss=1.2309, F1 Score=0.5142
# Epoch 191/200 | Train: Loss=1.2605, F1 Score=0.5294 | Val: Loss=1.2311, F1 Score=0.4999
# Epoch 192/200 | Train: Loss=1.2593, F1 Score=0.5325 | Val: Loss=1.2302, F1 Score=0.5069
# Epoch 193/200 | Train: Loss=1.2578, F1 Score=0.5349 | Val: Loss=1.2299, F1 Score=0.5125
# Epoch 194/200 | Train: Loss=1.2592, F1 Score=0.5327 | Val: Loss=1.2310, F1 Score=0.5060
# Epoch 195/200 | Train: Loss=1.2632, F1 Score=0.5245 | Val: Loss=1.2283, F1 Score=0.5203
# Epoch 196/200 | Train: Loss=1.2587, F1 Score=0.5300 | Val: Loss=1.2297, F1 Score=0.5140
# Epoch 197/200 | Train: Loss=1.2570, F1 Score=0.5349 | Val: Loss=1.2295, F1 Score=0.5087
# Epoch 198/200 | Train: Loss=1.2577, F1 Score=0.5373 | Val: Loss=1.2289, F1 Score=0.5043
# Epoch 199/200 | Train: Loss=1.2601, F1 Score=0.5299 | Val: Loss=1.2300, F1 Score=0.5045
# Epoch 200/200 | Train: Loss=1.2611, F1 Score=0.5307 | Val: Loss=1.2298, F1 Score=0.5168
# Best model restored from epoch 184 with val_f1 0.5228

# %% [markdown]
# ## Evaluation

# %%
# @title Plot Hitory
# Create a figure with two side-by-side subplots (two columns)
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(18, 5))

# Plot of training and validation loss on the first axis
ax1.plot(training_history['train_loss'], label='Training loss', alpha=0.3, color='#ff7f0e', linestyle='--')
ax1.plot(training_history['val_loss'], label='Validation loss', alpha=0.9, color='#ff7f0e')
ax1.set_title('Loss')
ax1.legend()
ax1.grid(alpha=0.3)

# Plot of training and validation accuracy on the second axis
ax2.plot(training_history['train_f1'], label='Training f1', alpha=0.3, color='#ff7f0e', linestyle='--')
ax2.plot(training_history['val_f1'], label='Validation f1', alpha=0.9, color='#ff7f0e')
ax2.set_title('F1 Score')
ax2.legend()
ax2.grid(alpha=0.3)

# Adjust the layout and display the plot
plt.tight_layout()
plt.subplots_adjust(right=0.85)
plt.show()

# %%
# @title Plot Confusion Matrix
# Collect predictions and ground truth labels
val_preds, val_targets = [], []
with torch.no_grad():  # Disable gradient computation for inference
    for xb, yb in val_loader:
        xb = xb.to(device)
        # Permute dimensions from (batch_size, height, width, channels) to (batch_size, channels, height, width)
        # This line is now redundant and incorrect as data is already (Batch, Channels, Height, Width)
        # xb = xb.permute(0, 3, 1, 2)

        # Forward pass: get model predictions
        logits = cnn_model(xb)
        preds = logits.argmax(dim=1).cpu().numpy()

        # Store batch results
        val_preds.append(preds)
        val_targets.append(yb.numpy())

# Combine all batches into single arrays
val_preds = np.concatenate(val_preds)
val_targets = np.concatenate(val_targets)

# Calculate overall validation metrics
val_acc = accuracy_score(val_targets, val_preds)
val_prec = precision_score(val_targets, val_preds, average='weighted')
val_rec = recall_score(val_targets, val_preds, average='weighted')
val_f1 = f1_score(val_targets, val_preds, average='weighted')
print(f"Accuracy over the validation set: {val_acc:.4f}")
print(f"Precision over the validation set: {val_prec:.4f}")
print(f"Recall over the validation set: {val_rec:.4f}")
print(f"F1 score over the validation set: {val_f1:.4f}")

# Generate confusion matrix for detailed error analysis
cm = confusion_matrix(val_targets, val_preds)

# Create numeric labels for heatmap annotation
labels = np.array([f"{num}" for num in cm.flatten()]).reshape(cm.shape)

# Visualise confusion matrix
plt.figure(figsize=(8, 7))
sns.heatmap(cm, annot=labels, fmt='',
            cmap='Blues')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix — Validation Set')
plt.tight_layout()
plt.show()
# Out:
# Accuracy over the validation set: 0.5331
# Precision over the validation set: 0.5519
# Recall over the validation set: 0.5331
# F1 score over the validation set: 0.5225

# %% [markdown]
# ## Hyperparameter Tuning

# %%
# ----------------------------
# Hyperparameter search space
# ----------------------------

def grid_search(
    param_grid,
    input_shape,
    num_classes,
    train_loader,
    val_loader,
    criterion,
    device,
    base_config=None,
    max_epochs=100,
    patience=15,
    weight_decay=0.0,
    verbose=1,
    save_path="models/best_resnet_grid_search.pt"
):
    """
    Performs grid search over hyperparameters for the CNN model.

    param_grid: dict of lists
    base_config: optional dictionary of CNN parameters to keep fixed
    """

    import itertools
    import copy

    # Expand hyperparameter grid
    all_configs = list(itertools.product(*param_grid.values()))
    print(f"\nTotal configurations: {len(all_configs)}\n")

    results = []
    best_score = -float("inf")
    best_params = None
    best_model_state = None

    # Training loop over all combinations
    for config in all_configs:
        hparams = dict(zip(param_grid.keys(), config))

        # Merge with fixed parameters (if provided)
        if base_config:
            full_params = {**base_config, **hparams}
        else:
            full_params = hparams

        print("\n========================================")
        print("Testing configuration:", full_params)
        print("========================================")


        # Build model using supplied parameters
        model = ResNetModel(
            input_shape=input_shape,
            output_shape=num_classes,
            filters=full_params["filters"],
            kernel_size=full_params["kernel_size"],
            stack=full_params["stack"],

        ).to(device)

        # Optimizer
        optimizer = torch.optim.AdamW(
            model.parameters(),
            lr=full_params["lr"],
            weight_decay=weight_decay
        )

        # AMP scaler
        scaler = torch.amp.GradScaler(enabled=(device.type == 'cuda'))

        # Train model
        model, history = fit(
            model=model,
            train_loader=train_loader,
            val_loader=val_loader,
            epochs=max_epochs,
            criterion=criterion,
            optimizer=optimizer,
            scaler=scaler,
            scheduler=scheduler,
            device=device,
            patience=patience,
            experiment_name="grid_temp",
            verbose=0,
        )

        # Score to compare models
        val_f1 = np.max(history["val_f1"])
        print(f" → F1 Score: {val_f1:.4f}")

        # Save results
        row = full_params.copy()
        row["val_f1"] = val_f1
        results.append(row)

        # Track best model
        if val_f1 > best_score:
            best_score = val_f1
            best_params = full_params.copy()
            best_model_state = copy.deepcopy(model.state_dict())

        # Free GPU memory
        del model
        torch.cuda.empty_cache()

    # Save best model
    torch.save(best_model_state, save_path)

    print("\n========================")
    print("Best hyperparameters:")
    print(best_params)
    print("Best F1:", best_score)
    print("========================")

    # Return results as DataFrame
    return pd.DataFrame(results), best_params, best_score

# %%
param_grid = {
    "filters": [16, 32, 64],
    "kernel_size": [3, 5],
    "stack": [1, 2, 3],
    "blocks": [1, 2, 3],
    "learning_rate": [1e-3, 3e-4, 1e-4],
}


# Fixed parameters (architecture options you don't want to grid-search)
base_config = {
    "lr": LEARNING_RATE,
    "weight_decay": L2_LAMBDA
}

df_results, best_params, best_score = grid_search(
    param_grid=param_grid,
    input_shape=input_shape,
    num_classes=num_classes,
    train_loader=train_loader,
    val_loader=val_loader,
    criterion=criterion,
    device=device,
    base_config=base_config,
    weight_decay=L2_LAMBDA,
    max_epochs=50,
    patience=15,
    save_path="models/best_resnet_grid_search.pt"
)
# Out:
# Total configurations: 162
#
#
# ========================================
# Testing configuration: {'lr': 0.0003, 'weight_decay': 0.0001, 'filters': 16, 'kernel_size': 3, 'stack': 1, 'blocks': 1, 'learning_rate': 0.001}
# ========================================
# Training 50 epochs...

# %%
df_results

# %% [markdown]
# ## Inference

# %%
cnn_model = best_model

# %%
list_preds = []
list_idx = []
with torch.no_grad():  # Disable gradient computation for inference
    for batch_idx, xb in enumerate(test_loader):
        xb = xb.to(device)

        # permute inputs (This line is incorrect as the data is already in the correct format (Batch, Channels, Height, Width))
        # xb = xb.permute(0, 3, 1, 2)

        # Forward pass: get model predictions
        logits = cnn_model(xb)
        preds = logits.argmax(dim=1).cpu().numpy()

        # Store batch results
        list_preds.append(preds)

        # Calculate the actual sample indices for this batch
        start_index = batch_idx * EVAL_BATCH_SIZE
        current_batch_size = len(preds) # Use len(preds) to handle the last batch possibly being smaller
        batch_sample_indices = np.arange(start_index, start_index + current_batch_size)
        list_idx.append(batch_sample_indices)

# Combine all batches into single arrays
list_preds = np.concatenate(list_preds)
list_idx = np.concatenate(list_idx)

# Create a DataFrame for the predictions
df_preds = pd.DataFrame({"sample_index": list_idx, "label": list_preds})

# %%
all_preds = []
all_image_ids = []

with torch.no_grad():
    for xb, image_ids in test_loader:
        xb = xb.to(device)

        logits = cnn_model(xb)
        preds = logits.argmax(dim=1).cpu().numpy()

        all_preds.extend(preds)
        # Fix: Remove .numpy() as image_ids is already a list/tuple of strings
        all_image_ids.extend(image_ids)

# Aggregate per image
df_tiles = pd.DataFrame({
    "image_id": all_image_ids,
    "pred": all_preds
})

final_preds = {}

for img_id, group in df_tiles.groupby("image_id"):
    final_preds[img_id] = group["pred"].mode()[0]   # majority vote

# Make submission df
df_preds = pd.DataFrame({
    "sample_index": list(final_preds.keys()),
    "label": list(final_preds.values())
}).sort_values("sample_index")

print(df_preds)
# Out:
#      sample_index  label
# 0    img_0000.png      2
# 1    img_0001.png      2
# 2    img_0002.png      1
# 3    img_0003.png      2
# 4    img_0004.png      2
# ..            ...    ...
# 472  img_0472.png      2
# 473  img_0473.png      3
# 474  img_0474.png      2
# 475  img_0475.png      1
# 476  img_0476.png      2
#
# [477 rows x 2 columns]

# %%
# mapping labels
mapping = {0: 'Triple negative',
             1: 'Luminal A',
             2: 'Luminal B',
             3: 'HER2(+)'}

df_preds['label'] = df_preds['label'].map(mapping)
#df_preds["sample_index"] = df_preds["sample_index"].apply(lambda x: f"img_{int(x):04d}.png")

# %%
df_preds.head()
# Out:
#    sample_index      label
# 0  img_0000.png  Luminal B
# 1  img_0001.png  Luminal B
# 2  img_0002.png  Luminal A
# 3  img_0003.png  Luminal B
# 4  img_0004.png  Luminal B

# %%
df_preds.to_csv('predictions.csv', index=False, header=True)
